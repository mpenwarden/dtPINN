# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
# Add source and data file paths
import os
path = os.path.abspath(os.getcwd())
os.chdir("../..")
parent_path = os.path.abspath(os.getcwd())

import sys 
sys.path.insert(1, parent_path + '\\source')
sys.path.insert(2, parent_path + '\\data')

import numpy as np; import torch; import time

# Import source/helper functions
from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
pde_type = 'new'
newParams = {}; newParams['data'] = parent_path+'\\data\\convec_long.mat'; newParams['pde'] = 'u_t + 30*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 1; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
dirichlet_bc = 0 # Use Dirichlet boundary condtions based on reference solution (0 = no, 1 = yes), number of points will depend on reference solution not user-defined N_b
learned_weights = 0 
lambda_w = 100 # Weight applied to non PDE-reisudal loss terms

### Training data parameters
N_x = 100; N_t = 500; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 200 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 10; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 1 # Number of continuously training segments
causal_dS = 1 # Boolean for adding in intial dS segments causality or not (0 = no, 1 = yes)
stacked_tol = 1*10**(-7)

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['u'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
#window_scheme = 'erf'
#scheme_parameters = (50, 10**(-8), 10**(-2), 1, 10**(-5)) 
window_scheme = 'none'
scheme_parameters = [2*10**(-1), 10**(-9), 1*10**(-2), 1]
# [(If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale; 
# If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance; 
# If 'causual_weights': epsilon), bound tolerance]

userPar = get_userPar(path, pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol, lambda_w, dirichlet_bc)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['animation'] = 0; # Boolean for showing/saving snapshots to make animation. If 0, it will just show/save the end of training
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'convection_long_dS-1_ic-u' # Name of file to save training snapshots under
userPar['show_fig'] = 1; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
SEED = 0

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 0

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1
lbfgs_loops = 300
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 42.7269
# epoch 200, loss: 32.3165
# epoch 300, loss: 19.0475
# epoch 400, loss: 8.77576
# epoch 500, loss: 5.84944
# Training time: 13.0719
# Train L-BFGS:
# epoch 100, loss: 4.20388, delta loss: 0.0114422
# epoch 200, loss: 3.39393, delta loss: 0.00520635
# epoch 300, loss: 2.96524, delta loss: 0.00479841
# epoch 400, loss: 2.5549, delta loss: 0.00219035
# epoch 500, loss: 2.11434, delta loss: 0.00404072
# Training time: 31.8489
# Train L-BFGS:
# epoch 100, loss: 1.7631, delta loss: 0.00273585
# epoch 200, loss: 1.06189, delta loss: 0.0084697
# epoch 300, loss: 0.41137, delta loss: 0.00343215
# epoch 400, loss: 0.167317, delta loss: 0.00156048
# epoch 500, loss: 0.0960007, delta loss: 0.000429533
# Training time: 50.6550
# Train L-BFGS:
# epoch 100, loss: 0.0591857, delta loss: 0.0002027
# epoch 200, loss: 0.0378806, delta loss: 0.000105001
# epoch 300, loss: 0.0259358, delta loss: 6.82473e-05
# epoch 400, loss: 0.0187632, delta loss: 8.169e-05
# epoch 500, loss: 0.0132942, delta loss: 2.87527e-05
# Training time: 69.2111
# Train L-BFGS:
# epoch 100, loss: 0.0107791, delta loss: 2.07871e-05
# epoch 200, loss: 0.00909755, delta loss: 7.70763e-06
# epoch 300, loss: 0.00745311, delta loss: 1.37361e-05
# epoch 400, loss: 0.00612965, delta loss: 1.47731e-05
# epoch 500, loss: 0.00513731, delta loss: 1.48434e-05
# Training time: 87.3114
# Train L-BFGS:
# epoch 100, loss: 0.00441586, delta loss: 7.45524e-06
# epoch 200, loss: 0.00376356, delta loss: 4.23542e-06
# epoch 300, loss: 0.00336192, delta loss: 2.71387e-06
# epoch 400, loss: 0.0029365, delta loss: 4.27128e-06
# epoch 500, loss: 0.00268459, delta loss: 2.13203e-06
# Training time: 105.8465
# Train L-BFGS:
# epoch 100, loss: 0.0024616, delta loss: 2.09268e-06
# epoch 200, loss: 0.0022715, delta loss: 1.87219e-06
# epoch 300, loss: 0.00205483, delta loss: 2.17371e-06
# epoch 400, loss: 0.00189655, delta loss: 1.29943e-06
# epoch 500, loss: 0.0018033, delta loss: 2.60375e-06
# Training time: 123.6519
# Train L-BFGS:
# epoch 100, loss: 0.00168789, delta loss: 1.50374e-06
# epoch 200, loss: 0.00152947, delta loss: 1.60921e-06
# epoch 300, loss: 0.00142684, delta loss: 9.60077e-07
# epoch 400, loss: 0.00133799, delta loss: 3.97675e-07
# epoch 500, loss: 0.00127726, delta loss: 5.61005e-07
# Training time: 141.3423
# Train L-BFGS:
# epoch 100, loss: 0.00118613, delta loss: 1.1588e-06
# epoch 200, loss: 0.00111287, delta loss: 4.96628e-07
# epoch 300, loss: 0.00106743, delta loss: 3.03844e-07
# epoch 400, loss: 0.00102382, delta loss: 7.27479e-07
# epoch 500, loss: 0.000951833, delta loss: 8.26665e-07
# Training time: 159.2656
# Train L-BFGS:
# epoch 100, loss: 0.000890857, delta loss: 7.70669e-07
# epoch 200, loss: 0.000828479, delta loss: 5.17175e-07
# epoch 300, loss: 0.000788611, delta loss: 4.34753e-07
# epoch 400, loss: 0.000743185, delta loss: 2.65194e-07
# epoch 500, loss: 0.000713109, delta loss: 3.0495e-07
# Training time: 177.2619
# Train L-BFGS:
# epoch 100, loss: 0.000677771, delta loss: 4.52681e-07
# epoch 200, loss: 0.000642672, delta loss: 2.86789e-07
# epoch 300, loss: 0.00061828, delta loss: 1.47615e-07
# epoch 400, loss: 0.000594556, delta loss: 2.64612e-07
# epoch 500, loss: 0.000566887, delta loss: 2.43017e-07
# Training time: 195.0696
# Train L-BFGS:
# epoch 100, loss: 0.000540676, delta loss: 1.89699e-07
#
# New Partition
#
# Training time: 204.7545
# Train L-BFGS:
# epoch 100, loss: 6.94669, delta loss: 0.0379028
# epoch 200, loss: 4.91272, delta loss: 0.0310116
# epoch 300, loss: 3.98764, delta loss: 0.0127776
# epoch 400, loss: 3.47107, delta loss: 0.0021925
# epoch 500, loss: 3.22775, delta loss: 0.00259447
# Training time: 223.5276
# Train L-BFGS:
# epoch 100, loss: 3.0659, delta loss: 0.00204206
# epoch 200, loss: 2.8939, delta loss: 0.00248861
# epoch 300, loss: 2.63741, delta loss: 0.0019207
# epoch 400, loss: 2.49724, delta loss: 0.00123477
# epoch 500, loss: 2.32884, delta loss: 0.00165868
# Training time: 242.8189
# Train L-BFGS:
# epoch 100, loss: 2.18521, delta loss: 0.000873327
# epoch 200, loss: 2.04694, delta loss: 0.0011127
# epoch 300, loss: 1.89885, delta loss: 0.00327277
# epoch 400, loss: 1.52706, delta loss: 0.00317299
# epoch 500, loss: 1.05824, delta loss: 0.00579238
# Training time: 261.3510
# Train L-BFGS:
# epoch 100, loss: 0.536653, delta loss: 0.00285244
# epoch 200, loss: 0.323106, delta loss: 0.00166026
# epoch 300, loss: 0.187118, delta loss: 0.000839934
# epoch 400, loss: 0.111561, delta loss: 0.000533789
# epoch 500, loss: 0.0721121, delta loss: 0.000225194
# Training time: 280.1279
# Train L-BFGS:
# epoch 100, loss: 0.0523448, delta loss: 0.000229161
# epoch 200, loss: 0.0432211, delta loss: 4.96134e-05
# epoch 300, loss: 0.0364089, delta loss: 5.10775e-05
# epoch 400, loss: 0.029369, delta loss: 7.22036e-05
# epoch 500, loss: 0.0232481, delta loss: 3.20878e-05
# Training time: 298.7950
# Train L-BFGS:
# epoch 100, loss: 0.0196943, delta loss: 2.12509e-05
# epoch 200, loss: 0.0170298, delta loss: 2.88412e-05
# epoch 300, loss: 0.0143004, delta loss: 2.57557e-05
# epoch 400, loss: 0.0119001, delta loss: 1.79084e-05
# epoch 500, loss: 0.0104606, delta loss: 2.91206e-05
# Training time: 317.2099
# Train L-BFGS:
# epoch 100, loss: 0.0090543, delta loss: 9.57679e-06
# epoch 200, loss: 0.00792146, delta loss: 7.10227e-06
# epoch 300, loss: 0.00715963, delta loss: 7.55535e-06
# epoch 400, loss: 0.00627658, delta loss: 6.05173e-06
# epoch 500, loss: 0.00567826, delta loss: 1.04695e-05
# Training time: 336.4649
# Train L-BFGS:
# epoch 100, loss: 0.00514042, delta loss: 5.82356e-06
# epoch 200, loss: 0.00468083, delta loss: 3.98327e-06
# epoch 300, loss: 0.00428855, delta loss: 2.88617e-06
# epoch 400, loss: 0.0039103, delta loss: 3.80911e-06
# epoch 500, loss: 0.00363349, delta loss: 3.77465e-06
# Training time: 356.0153
# Train L-BFGS:
# epoch 100, loss: 0.00334838, delta loss: 3.77768e-06
# epoch 200, loss: 0.00306549, delta loss: 2.38954e-06
# epoch 300, loss: 0.00292336, delta loss: 1.10897e-06
# epoch 400, loss: 0.00280089, delta loss: 1.79675e-06
# epoch 500, loss: 0.00268568, delta loss: 1.19605e-06
# Training time: 376.1815
# Train L-BFGS:
# epoch 100, loss: 0.00257503, delta loss: 9.73698e-07
# epoch 200, loss: 0.00247879, delta loss: 6.48201e-07
# epoch 300, loss: 0.00238084, delta loss: 1.2361e-06
# epoch 400, loss: 0.00227431, delta loss: 1.01677e-06
# epoch 500, loss: 0.00221543, delta loss: 8.53324e-07
# Training time: 396.0138
# Train L-BFGS:
# epoch 100, loss: 0.00214266, delta loss: 5.03613e-07
# epoch 200, loss: 0.00206344, delta loss: 4.53787e-07
# epoch 300, loss: 0.00200094, delta loss: 8.99192e-07
# epoch 400, loss: 0.00193394, delta loss: 6.5309e-07
# epoch 500, loss: 0.001887, delta loss: 4.58676e-07
# Training time: 415.6720
# Train L-BFGS:
# epoch 100, loss: 0.00184033, delta loss: 4.0431e-07
# epoch 200, loss: 0.00178689, delta loss: 5.20027e-07
# epoch 300, loss: 0.00175167, delta loss: 2.63564e-07
# epoch 400, loss: 0.00171225, delta loss: 3.52855e-07
# epoch 500, loss: 0.00167638, delta loss: 4.40399e-07
# Training time: 435.9815
# Train L-BFGS:
#
# New Partition
#
# Training time: 445.8626
# Train L-BFGS:
# epoch 100, loss: 6.22047e+07, delta loss: 488952
# epoch 200, loss: 4.90564e+07, delta loss: 503224
# epoch 300, loss: 2.48334e+19, delta loss: 0
# epoch 400, loss: 2.48334e+19, delta loss: 0
# epoch 500, loss: 2.48334e+19, delta loss: 0
# Training time: 466.1278
# Train L-BFGS:
# epoch 100, loss: 2.48334e+19, delta loss: 0
# epoch 200, loss: 2.48334e+19, delta loss: 0
# epoch 300, loss: 2.48334e+19, delta loss: 0
# epoch 400, loss: 2.48334e+19, delta loss: 0
# epoch 500, loss: 2.48334e+19, delta loss: 0
# Training time: 487.2659
# Train L-BFGS:
# epoch 100, loss: 2.48334e+19, delta loss: 0
# epoch 200, loss: 2.48334e+19, delta loss: 0
# epoch 300, loss: 2.48334e+19, delta loss: 0
# epoch 400, loss: 2.48334e+19, delta loss: 0
# epoch 500, loss: 2.48334e+19, delta loss: 0
# Training time: 508.1236
# Train L-BFGS:
# epoch 100, loss: 2.48334e+19, delta loss: 0
# epoch 200, loss: 2.48334e+19, delta loss: 0
# epoch 300, loss: 2.48334e+19, delta loss: 0
# epoch 400, loss: 2.48334e+19, delta loss: 0
# epoch 500, loss: 2.48334e+19, delta loss: 0
# Training time: 528.9279
# Train L-BFGS:
# epoch 100, loss: 2.48334e+19, delta loss: 0
# epoch 200, loss: 2.48334e+19, delta loss: 0
# epoch 300, loss: 2.48334e+19, delta loss: 0
# epoch 400, loss: 2.48334e+19, delta loss: 0
# epoch 500, loss: 2.48334e+19, delta loss: 0
# Training time: 549.8327
# Train L-BFGS:
# epoch 100, loss: 2.48334e+19, delta loss: 0
# epoch 200, loss: 2.48334e+19, delta loss: 0
# epoch 300, loss: 2.48334e+19, delta loss: 0
# epoch 400, loss: 2.48334e+19, delta loss: 0
# epoch 500, loss: 2.48334e+19, delta loss: 0
# Training time: 568.7037
# Train L-BFGS:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-defae96d07f0> in <module>
#       1 adam_loops = 1
#       2 lbfgs_loops = 300
# ----> 3 model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
#
# G:\My Drive\Research\Notebook files\dtPINN\source\misc_helper.py in training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
#     108         print('Train L-BFGS:')
#     109         start_time = time.time() # Track training time
# --> 110         optim_state_dict, optimizer, iterations, new_partition, end_condition = model.train_lbfgs(optim_state, optim_state_dict, optimizer)
#     111         elapsed = time.time() - start_time
#     112         train_time += elapsed
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in train_lbfgs(self, optim_state, optim_state_dict, optimizer)
#     476                 return self.prev_loss
#     477
# --> 478         optimizer.step(closure)
#     479
#     480         # Check for stacked decomp condition
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\optim\lbfgs.py in step(self, closure)
#     436                     with torch.enable_grad():
#     437                         loss = float(closure())
# --> 438                     flat_grad = self._gather_flat_grad()
#     439                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#     440                     ls_func_evals = 1
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\optim\lbfgs.py in _gather_flat_grad(self)
#     253                 view = p.grad.to_dense().view(-1)
#     254             else:
# --> 255                 view = p.grad.view(-1)
#     256             views.append(view)
#     257         return torch.cat(views, 0)
#
# KeyboardInterrupt:
