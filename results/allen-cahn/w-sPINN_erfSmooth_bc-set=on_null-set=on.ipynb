# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
# Add source and data file paths
import os
path = os.path.abspath(os.getcwd())
os.chdir("../..")
parent_path = os.path.abspath(os.getcwd())

import sys
sys.path.insert(1, parent_path + '\\source')
sys.path.insert(2, parent_path + '\\data')

import numpy as np; import torch; import time

# Import source/helper functions
from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
pde_type = 'allen-cahn'
newParams = {}

#pde_type = 'new'
#newParams = {}; newParams['data'] = parent_path+'\\data\\convec_10.mat'; newParams['pde'] = 'u_t + 10*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 10; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
dirichlet_bc = 0 # Use Dirichlet boundary condtions based on reference solution (0 = no, 1 = yes), number of points will depend on reference solution not user-defined N_b
learned_weights = 0 
lambda_w = 100 # Weight applied to non PDE-reisudal loss terms

### Training data parameters
N_x = 100; N_t = 100; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 200 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 1; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 1 # Number of continuously training segments
causal_dS = 1 # Boolean for adding in intial dS segments causality or not (0 = no, 1 = yes)
stacked_tol = 1*10**(-8)

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['u'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
#window_scheme = 'erf'
#scheme_parameters = (50, 10**(-8), 10**(-2), 1, 10**(-5)) 
window_scheme = 'erf'
scheme_parameters = [52.5, 1*10**(-7), 0.125*10**(-1), 1, 10**(-4), 1, 1]

# If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale, use bc-set, use null-set; 
# If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance, use bc-set, use null-set; 
# If 'causual_weights': epsilon), bound tolerance

userPar = get_userPar(path, pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol, lambda_w, dirichlet_bc)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['animation'] = 0; # Boolean for showing/saving snapshots to make animation. If 0, it will just show/save the end of training
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'allenCahn_erfSmooth_8dt_bc-set=on_null-set=on' # Name of file to save training snapshots under
userPar['show_fig'] = 1; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
userPar['log'] = 1; # Logs rel L2 error, runtime, loss over iterations, prediction, etc.
SEED = 0

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 0

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1
lbfgs_loops = 300
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 0.266197, delta loss: 0.000942707
# epoch 200, loss: 0.208965, delta loss: 0.000347823
# epoch 300, loss: 0.179981, delta loss: 0.000289813
# epoch 400, loss: 0.144305, delta loss: 0.000450149
# epoch 500, loss: 0.0840795, delta loss: 0.000750415
# Training time: 12.2707
# Train L-BFGS:
# epoch 100, loss: 0.00402491, delta loss: 7.45677e-05
# epoch 200, loss: 0.00151226, delta loss: 5.74195e-06
# epoch 300, loss: 0.00107814, delta loss: 2.46987e-06
# epoch 400, loss: 0.000919791, delta loss: 1.02184e-06
# epoch 500, loss: 0.000822237, delta loss: 1.17678e-06
# Training time: 27.6260
# Train L-BFGS:
# epoch 100, loss: 0.000728672, delta loss: 1.19134e-06
# epoch 200, loss: 0.000637368, delta loss: 5.56756e-07
# epoch 300, loss: 0.000565079, delta loss: 6.14498e-07
# epoch 400, loss: 0.000502373, delta loss: 5.38479e-07
# epoch 500, loss: 0.000439242, delta loss: 9.14733e-07
# Training time: 41.4716
# Train L-BFGS:
# epoch 100, loss: 0.000372805, delta loss: 4.03612e-07
# epoch 200, loss: 0.00028906, delta loss: 9.23988e-07
# epoch 300, loss: 0.000219347, delta loss: 8.23027e-07
# epoch 400, loss: 0.000167959, delta loss: 5.6818e-07
# epoch 500, loss: 0.000138998, delta loss: 3.60786e-07
# Training time: 55.3672
# Train L-BFGS:
# epoch 100, loss: 0.000119125, delta loss: 1.86468e-07
# epoch 200, loss: 0.000100415, delta loss: 2.53567e-07
#
# Propogate
#
# epoch 300, loss: 0.000131763, delta loss: 6.21818e-07
#
# Propogate
#
# epoch 400, loss: 0.000138594, delta loss: 6.76431e-07
#
# Propogate
#
# epoch 500, loss: 0.000246466, delta loss: 2.82453e-07
# Training time: 69.7466
# Train L-BFGS:
# epoch 100, loss: 0.000166498, delta loss: 1.79061e-07
#
# Propogate
#
# epoch 200, loss: 0.000197772, delta loss: 2.7944e-07
# epoch 300, loss: 0.000173493, delta loss: 1.95316e-07
#
# Propogate
#
# epoch 400, loss: 0.000280813, delta loss: 2.03698e-07
# epoch 500, loss: 0.000194819, delta loss: 4.82672e-07
# Training time: 85.1807
# Train L-BFGS:
# epoch 100, loss: 0.000164529, delta loss: 2.75293e-07
# epoch 200, loss: 0.000141742, delta loss: 2.04105e-07
#
# Propogate
#
# epoch 300, loss: 0.000186699, delta loss: 1.14372e-06
# epoch 400, loss: 0.000150435, delta loss: 2.09897e-07
# epoch 500, loss: 0.000131434, delta loss: 1.59038e-07
# Training time: 100.9477
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000150751, delta loss: 2.00409e-07
#
# Propogate
#
# epoch 200, loss: 0.000162555, delta loss: 2.538e-07
#
# Propogate
#
# epoch 300, loss: 0.000188561, delta loss: 1.22652e-06
# epoch 400, loss: 0.000160317, delta loss: 1.31156e-07
#
# Propogate
#
# epoch 500, loss: 0.000180502, delta loss: 1.6726e-07
# Training time: 117.2989
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000216741, delta loss: 2.75948e-07
# epoch 200, loss: 0.00019074, delta loss: 3.01792e-07
# epoch 300, loss: 0.000173009, delta loss: 1.66605e-07
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.000268789, delta loss: 1.0457e-06
# epoch 500, loss: 0.000218164, delta loss: 1.99216e-07
# Training time: 134.6424
# Train L-BFGS:
# epoch 100, loss: 0.000198284, delta loss: 1.70025e-07
#
# Propogate
#
# epoch 200, loss: 0.000292412, delta loss: 3.97908e-07
# epoch 300, loss: 0.000211259, delta loss: 3.06085e-07
# epoch 400, loss: 0.000185974, delta loss: 1.53625e-07
#
# Propogate
#
# epoch 500, loss: 0.000218154, delta loss: 3.50541e-07
# Training time: 151.1344
# Train L-BFGS:
# epoch 100, loss: 0.000191008, delta loss: 2.31041e-07
# epoch 200, loss: 0.000166807, delta loss: 2.00278e-07
#
# Propogate
#
#
# Propogate
#
# epoch 300, loss: 0.000351553, delta loss: 5.16645e-06
# epoch 400, loss: 0.000197445, delta loss: 7.41435e-07
# epoch 500, loss: 0.000169961, delta loss: 2.0671e-07
# Training time: 167.8399
# Train L-BFGS:
# epoch 100, loss: 0.000150455, delta loss: 1.62836e-07
#
# Propogate
#
#
# Propogate
#
# epoch 200, loss: 0.000312113, delta loss: 1.65691e-06
# epoch 300, loss: 0.000176726, delta loss: 2.70578e-07
# epoch 400, loss: 0.000152281, delta loss: 1.93744e-07
# epoch 500, loss: 0.000131404, delta loss: 2.20636e-07
# Training time: 184.4436
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000174721, delta loss: 3.65777e-07
# epoch 200, loss: 0.000132139, delta loss: 2.38855e-07
#
# Propogate
#
# epoch 300, loss: 0.000136481, delta loss: 2.02272e-07
# epoch 400, loss: 0.000114762, delta loss: 1.58449e-07
# epoch 500, loss: 9.66296e-05, delta loss: 1.38614e-07
# Training time: 201.9072
# Train L-BFGS:
#
# Propogate
#
#
# Propogate
#
# epoch 100, loss: 0.000142546, delta loss: 4.28842e-05
# epoch 200, loss: 0.00010822, delta loss: 1.31156e-07
#
# Propogate
#
# epoch 300, loss: 0.00011847, delta loss: 1.53865e-07
#
# Propogate
#
# epoch 400, loss: 0.000125281, delta loss: 1.82758e-07
#
# Propogate
#
# epoch 500, loss: 0.000135499, delta loss: 7.49424e-07
# Training time: 218.9513
# Train L-BFGS:
# epoch 100, loss: 0.000114641, delta loss: 1.42842e-07
#
# Propogate
#
#
# Propogate
#
# epoch 200, loss: 0.000148857, delta loss: 2.4584e-07
# epoch 300, loss: 0.000128035, delta loss: 3.43847e-07
#
# Propogate
#
# epoch 400, loss: 0.000138879, delta loss: 5.49728e-07
#
# Propogate
#
# epoch 500, loss: 0.00014809, delta loss: 1.89408e-07
# Training time: 236.2058
# Train L-BFGS:
# epoch 100, loss: 0.000127625, delta loss: 2.29295e-07
#
# Propogate
#
# epoch 200, loss: 0.000144294, delta loss: 2.46859e-06
# epoch 300, loss: 0.000109692, delta loss: 1.12988e-07
#
# Propogate
#
# epoch 400, loss: 0.000122538, delta loss: 3.20753e-07
#
# Propogate
#
# epoch 500, loss: 0.000181744, delta loss: 3.96595e-06
# Training time: 254.0508
# Train L-BFGS:
# epoch 100, loss: 0.000126472, delta loss: 3.31784e-07
#
# Propogate
#
# epoch 200, loss: 0.000148898, delta loss: 1.92033e-06
#
# Propogate
#
# epoch 300, loss: 0.000147905, delta loss: 8.22532e-07
#
# Propogate
#
# epoch 400, loss: 0.000167748, delta loss: 6.31946e-07
#
# Propogate
#
# epoch 500, loss: 0.00018146, delta loss: 4.08094e-07
# Training time: 272.7112
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000212353, delta loss: 3.24246e-07
# epoch 200, loss: 0.000187969, delta loss: 2.07263e-07
#
# Propogate
#
# epoch 300, loss: 0.000259776, delta loss: 9.24968e-05
# epoch 400, loss: 0.000177277, delta loss: 1.62894e-07
#
# Propogate
#
# epoch 500, loss: 0.000248488, delta loss: 1.09954e-07
# Training time: 290.7185
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000205561, delta loss: 2.81245e-07
# epoch 200, loss: 0.00018178, delta loss: 1.83092e-07
# epoch 300, loss: 0.000159927, delta loss: 2.43948e-07
#
# Propogate
#
#
# Propogate
#
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.000862809, delta loss: 1.7202e-05
# epoch 500, loss: 0.000308605, delta loss: 1.70595e-06
# Training time: 310.1908
# Train L-BFGS:
# epoch 100, loss: 0.000237742, delta loss: 5.22734e-07
# epoch 200, loss: 0.000201664, delta loss: 2.37749e-07
# epoch 300, loss: 0.000174249, delta loss: 3.91752e-07
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.000506609, delta loss: 4.19363e-06
# epoch 500, loss: 0.000197521, delta loss: 7.65343e-07
# Training time: 331.1685
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000233693, delta loss: 2.30237e-06
# epoch 200, loss: 0.000184289, delta loss: 2.1352e-07
#
# Propogate
#
# epoch 300, loss: 0.000212362, delta loss: 1.67855e-06
# epoch 400, loss: 0.000172936, delta loss: 1.49928e-07
#
# Propogate
#
# epoch 500, loss: 0.000174025, delta loss: 2.7199e-07
# Training time: 351.8859
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.00017642, delta loss: 1.89277e-07
# epoch 200, loss: 0.00016013, delta loss: 1.52839e-07
#
# Propogate
#
# epoch 300, loss: 0.000168052, delta loss: 2.76879e-07
#
# Propogate
#
# epoch 400, loss: 0.000166599, delta loss: 3.54936e-07
#
# Propogate
#
#
# Propogate
#
# epoch 500, loss: 0.000215653, delta loss: 1.015e-06
# Training time: 373.4245
# Train L-BFGS:
# epoch 100, loss: 0.000178006, delta loss: 2.64743e-07
#
# Propogate
#
#
# Propogate
#
# epoch 200, loss: 0.000282793, delta loss: 1.46846e-06
# epoch 300, loss: 0.000218529, delta loss: 3.19633e-07
# epoch 400, loss: 0.000191203, delta loss: 2.40281e-07
#
# Propogate
#
# epoch 500, loss: 0.000205808, delta loss: 7.20946e-07
# Training time: 395.3700
# Train L-BFGS:
# epoch 100, loss: 0.000173316, delta loss: 1.47906e-07
#
# Propogate
#
# epoch 200, loss: 0.000181409, delta loss: 1.7893e-07
#
# Propogate
#
# epoch 300, loss: 0.000193091, delta loss: 3.02243e-07
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.000302316, delta loss: 3.34933e-06
# epoch 500, loss: 0.000217098, delta loss: 2.76341e-07
# Training time: 418.0936
# Train L-BFGS:
# epoch 100, loss: 0.000194149, delta loss: 2.53669e-07
#
# Propogate
#
# epoch 200, loss: 0.000222548, delta loss: 1.36079e-06
# epoch 300, loss: 0.000185063, delta loss: 1.65441e-07
#
# Propogate
#
# epoch 400, loss: 0.000192187, delta loss: 2.67653e-07
#
# Propogate
#
# epoch 500, loss: 0.000208164, delta loss: 2.61207e-07
# Training time: 440.0066
# Train L-BFGS:
# epoch 100, loss: 0.000182522, delta loss: 1.63913e-07
#
# Propogate
#
# epoch 200, loss: 0.000191703, delta loss: 2.18395e-07
#
# Propogate
#
# epoch 300, loss: 0.000198407, delta loss: 3.58617e-07
#
# Propogate
#
# epoch 400, loss: 0.000212705, delta loss: 1.37388e-06
# epoch 500, loss: 0.00018648, delta loss: 1.46771e-07
# Training time: 463.7784
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000186611, delta loss: 1.65048e-07
#
# Propogate
#
# epoch 200, loss: 0.000187829, delta loss: 3.04412e-07
#
# Propogate
#
# epoch 300, loss: 0.000345062, delta loss: 3.24639e-05
#
# Propogate
#
# epoch 400, loss: 0.000207068, delta loss: 4.06028e-07
#
# Propogate
#
# epoch 500, loss: 0.000214443, delta loss: 4.5661e-07
# Training time: 488.6148
# Train L-BFGS:
# epoch 100, loss: 0.000191429, delta loss: 2.29527e-07
#
# Propogate
#
# epoch 200, loss: 0.000193761, delta loss: 1.69239e-07
#
# Propogate
#
# epoch 300, loss: 0.000225195, delta loss: 7.93749e-07
# epoch 400, loss: 0.000194257, delta loss: 1.49361e-07
# epoch 500, loss: 0.000177373, delta loss: 1.81972e-07
# Training time: 510.4808
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000200178, delta loss: 4.86383e-07
# epoch 200, loss: 0.000169171, delta loss: 1.90077e-07
#
# Propogate
#
# epoch 300, loss: 0.000156696, delta loss: 1.74288e-07
#
# Propogate
#
# epoch 400, loss: 0.00016914, delta loss: 1.65697e-06
# epoch 500, loss: 0.000132982, delta loss: 1.35391e-07
# Training time: 530.7854
# Train L-BFGS:
#
# Propogate
#
#
# Propogate
#
#
# End Propogate
#
# epoch 100, loss: 0.000103953, delta loss: 6.34172e-08
# epoch 200, loss: 9.91556e-05, delta loss: 4.30664e-08
# epoch 300, loss: 9.32432e-05, delta loss: 5.67743e-08
# epoch 400, loss: 8.87657e-05, delta loss: 4.86398e-08
# epoch 500, loss: 8.37346e-05, delta loss: 3.87954e-08
# Training time: 544.9099
# Train L-BFGS:
# epoch 100, loss: 8.06136e-05, delta loss: 3.92247e-08
# epoch 200, loss: 7.81537e-05, delta loss: 4.06508e-08
# epoch 300, loss: 7.49887e-05, delta loss: 3.26763e-08
# epoch 400, loss: 7.25351e-05, delta loss: 2.18497e-08
# epoch 500, loss: 6.987e-05, delta loss: 1.80517e-08
# Training time: 559.4442
# Train L-BFGS:
# epoch 100, loss: 6.75006e-05, delta loss: 1.31113e-08
#
# End Condition
#
# Training time: 564.9975
# No Residual set
# L2-error:  0.042928074762287306
