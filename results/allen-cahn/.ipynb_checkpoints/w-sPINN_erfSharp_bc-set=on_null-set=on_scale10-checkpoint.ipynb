# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
# Add source and data file paths
import os
path = os.path.abspath(os.getcwd())
os.chdir("../..")
parent_path = os.path.abspath(os.getcwd())

import sys
sys.path.insert(1, parent_path + '\\source')
sys.path.insert(2, parent_path + '\\data')

import numpy as np; import torch; import time

# Import source/helper functions
from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
pde_type = 'allen-cahn'
newParams = {}

#pde_type = 'new'
#newParams = {}; newParams['data'] = parent_path+'\\data\\convec_10.mat'; newParams['pde'] = 'u_t + 10*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 10; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
dirichlet_bc = 0 # Use Dirichlet boundary condtions based on reference solution (0 = no, 1 = yes), number of points will depend on reference solution not user-defined N_b
learned_weights = 0 
lambda_w = 100 # Weight applied to non PDE-reisudal loss terms

### Training data parameters
N_x = 100; N_t = 100; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 200 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 1; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 1 # Number of continuously training segments
causal_dS = 1 # Boolean for adding in intial dS segments causality or not (0 = no, 1 = yes)
stacked_tol = 1*10**(-8)

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['u'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
#window_scheme = 'erf'
#scheme_parameters = (50, 10**(-8), 10**(-2), 1, 10**(-5)) 
window_scheme = 'erf'
scheme_parameters = [100, 1*10**(-7), 0.125*10**(-1), 1, 10**(-4), 1, 1]

# If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale, use bc-set, use null-set; 
# If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance, use bc-set, use null-set; 
# If 'causual_weights': epsilon), bound tolerance

userPar = get_userPar(path, pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol, lambda_w, dirichlet_bc)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['animation'] = 0; # Boolean for showing/saving snapshots to make animation. If 0, it will just show/save the end of training
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'allenCahn_erfSharp_8dt_bc-set=on_null-set=on' # Name of file to save training snapshots under
userPar['show_fig'] = 1; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
userPar['log'] = 1; # Logs rel L2 error, runtime, loss over iterations, prediction, etc.
SEED = 0

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 0

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1
lbfgs_loops = 300
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 0.279078, delta loss: 0.00101277
# epoch 200, loss: 0.218947, delta loss: 0.000361934
# epoch 300, loss: 0.187333, delta loss: 0.000332445
# epoch 400, loss: 0.144501, delta loss: 0.000557095
# epoch 500, loss: 0.0731763, delta loss: 0.000796035
# Training time: 11.2834
# Train L-BFGS:
# epoch 100, loss: 0.00327554, delta loss: 5.53983e-05
# epoch 200, loss: 0.000923633, delta loss: 7.29517e-06
# epoch 300, loss: 0.000556032, delta loss: 2.28093e-06
# epoch 400, loss: 0.000445333, delta loss: 1.01293e-06
# epoch 500, loss: 0.000373088, delta loss: 6.93981e-07
# Training time: 23.2396
# Train L-BFGS:
# epoch 100, loss: 0.000320171, delta loss: 3.99741e-07
# epoch 200, loss: 0.000280406, delta loss: 2.54455e-07
# epoch 300, loss: 0.00025744, delta loss: 2.4779e-07
# epoch 400, loss: 0.000236676, delta loss: 2.04411e-07
# epoch 500, loss: 0.000218434, delta loss: 1.601e-07
# Training time: 34.7399
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000500981, delta loss: 6.28969e-06
# epoch 200, loss: 0.00026351, delta loss: 3.63681e-07
#
# Propogate
#
# epoch 300, loss: 0.000605048, delta loss: 2.10262e-05
# epoch 400, loss: 0.000298771, delta loss: 7.21164e-07
#
# Propogate
#
# epoch 500, loss: 0.000712873, delta loss: 1.30351e-05
# Training time: 47.8588
# Train L-BFGS:
# epoch 100, loss: 0.000336983, delta loss: 1.13968e-06
# epoch 200, loss: 0.000279855, delta loss: 2.6956e-07
#
# Propogate
#
# epoch 300, loss: 0.000416211, delta loss: 1.93293e-06
# epoch 400, loss: 0.000360376, delta loss: 1.44733e-07
# epoch 500, loss: 0.000333592, delta loss: 3.45695e-07
# Training time: 62.0388
# Train L-BFGS:
# epoch 100, loss: 0.000312238, delta loss: 2.11119e-07
# epoch 200, loss: 0.000283024, delta loss: 1.69326e-07
# epoch 300, loss: 0.000252372, delta loss: 4.05416e-07
# epoch 400, loss: 0.00020432, delta loss: 3.02578e-07
#
# Propogate
#
# epoch 500, loss: 0.000431439, delta loss: 6.48433e-07
# Training time: 75.0677
# Train L-BFGS:
# epoch 100, loss: 0.000243507, delta loss: 7.06699e-07
# epoch 200, loss: 0.000214048, delta loss: 2.2848e-07
# epoch 300, loss: 0.000191233, delta loss: 1.71713e-07
#
# Propogate
#
# epoch 400, loss: 0.00028166, delta loss: 6.98259e-07
# epoch 500, loss: 0.000237388, delta loss: 2.68032e-07
# Training time: 88.3435
# Train L-BFGS:
# epoch 100, loss: 0.000198465, delta loss: 5.09099e-07
# epoch 200, loss: 0.000170122, delta loss: 2.20403e-07
# epoch 300, loss: 0.000137653, delta loss: 2.81085e-07
#
# Propogate
#
#
# Propogate
#
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.00173128, delta loss: 8.74011e-06
# epoch 500, loss: 0.000621007, delta loss: 6.55657e-06
# Training time: 102.0651
# Train L-BFGS:
# epoch 100, loss: 0.000347937, delta loss: 9.6485e-07
# epoch 200, loss: 0.000261756, delta loss: 6.3979e-07
# epoch 300, loss: 0.000220409, delta loss: 6.71338e-07
# epoch 400, loss: 0.000174075, delta loss: 1.93162e-07
# epoch 500, loss: 0.000150741, delta loss: 2.42813e-07
# Training time: 116.1656
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000204557, delta loss: 6.81466e-07
# epoch 200, loss: 0.000152687, delta loss: 1.23619e-07
#
# Propogate
#
# epoch 300, loss: 0.00017682, delta loss: 3.79019e-07
#
# Propogate
#
# epoch 400, loss: 0.000217128, delta loss: 1.02961e-06
#
# Propogate
#
# epoch 500, loss: 0.000221362, delta loss: 4.14628e-07
# Training time: 130.8103
# Train L-BFGS:
# epoch 100, loss: 0.00019008, delta loss: 1.68715e-07
#
# Propogate
#
# epoch 200, loss: 0.000268828, delta loss: 1.68511e-06
# epoch 300, loss: 0.0002026, delta loss: 2.19501e-07
#
# Propogate
#
# epoch 400, loss: 0.000239945, delta loss: 5.13654e-07
# epoch 500, loss: 0.0002098, delta loss: 1.89189e-07
# Training time: 145.0603
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000278932, delta loss: 1.09497e-06
# epoch 200, loss: 0.000228101, delta loss: 2.31696e-07
# epoch 300, loss: 0.000205175, delta loss: 1.11642e-07
# epoch 400, loss: 0.000186475, delta loss: 2.23692e-07
#
# Propogate
#
# epoch 500, loss: 0.000210321, delta loss: 1.90921e-07
# Training time: 158.6149
# Train L-BFGS:
# epoch 100, loss: 0.000184639, delta loss: 1.43002e-07
#
# Propogate
#
# epoch 200, loss: 0.000222536, delta loss: 6.65794e-07
# epoch 300, loss: 0.000194023, delta loss: 1.46305e-07
# epoch 400, loss: 0.000175818, delta loss: 2.35712e-07
#
# Propogate
#
# epoch 500, loss: 0.000274266, delta loss: 9.56381e-07
# Training time: 172.7094
# Train L-BFGS:
# epoch 100, loss: 0.00019988, delta loss: 4.17378e-07
# epoch 200, loss: 0.000173675, delta loss: 2.94749e-07
#
# Propogate
#
# epoch 300, loss: 0.000193741, delta loss: 4.93266e-07
# epoch 400, loss: 0.000169114, delta loss: 3.18134e-07
# epoch 500, loss: 0.000147416, delta loss: 1.52053e-07
# Training time: 186.5720
# Train L-BFGS:
#
# Propogate
#
#
# Propogate
#
# epoch 100, loss: 0.000218849, delta loss: 1.30835e-06
# epoch 200, loss: 0.000153807, delta loss: 2.60203e-07
#
# Propogate
#
#
# Propogate
#
# epoch 300, loss: 0.000257186, delta loss: 3.06315e-06
# epoch 400, loss: 0.000176115, delta loss: 5.90604e-07
# epoch 500, loss: 0.000146833, delta loss: 1.58208e-07
# Training time: 201.0224
# Train L-BFGS:
# epoch 100, loss: 0.000126914, delta loss: 1.41241e-07
#
# Propogate
#
#
# Propogate
#
# epoch 200, loss: 0.000206723, delta loss: 1.5944e-06
# epoch 300, loss: 0.000138063, delta loss: 2.54484e-07
# epoch 400, loss: 0.000120073, delta loss: 1.02795e-07
#
# Propogate
#
#
# Propogate
#
# epoch 500, loss: 0.000184256, delta loss: 8.27116e-07
# Training time: 215.0799
# Train L-BFGS:
# epoch 100, loss: 0.000146, delta loss: 2.94545e-07
#
# Propogate
#
# epoch 200, loss: 0.000170057, delta loss: 1.4496e-06
# epoch 300, loss: 0.000134028, delta loss: 1.1755e-07
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.000183898, delta loss: 5.30694e-07
# epoch 500, loss: 0.000144891, delta loss: 2.31972e-07
# Training time: 229.6693
# Train L-BFGS:
# epoch 100, loss: 0.000126978, delta loss: 1.02678e-07
#
# Propogate
#
# epoch 200, loss: 0.000139891, delta loss: 2.07685e-07
#
# Propogate
#
#
# Propogate
#
# epoch 300, loss: 0.000402128, delta loss: 1.03062e-06
# epoch 400, loss: 0.000182501, delta loss: 4.06944e-07
#
# Propogate
#
# epoch 500, loss: 0.000181961, delta loss: 2.93119e-07
# Training time: 244.6725
# Train L-BFGS:
# epoch 100, loss: 0.000151103, delta loss: 3.7752e-07
# epoch 200, loss: 0.0001289, delta loss: 1.34314e-07
#
# Propogate
#
# epoch 300, loss: 0.000146751, delta loss: 2.45229e-07
#
# Propogate
#
# epoch 400, loss: 0.000178324, delta loss: 3.92858e-07
#
# Propogate
#
# epoch 500, loss: 0.000227485, delta loss: 4.26079e-06
# Training time: 259.5038
# Train L-BFGS:
# epoch 100, loss: 0.000171259, delta loss: 3.95885e-07
# epoch 200, loss: 0.000152085, delta loss: 1.10696e-07
#
# Propogate
#
#
# Propogate
#
# epoch 300, loss: 0.000235081, delta loss: 1.09339e-06
# epoch 400, loss: 0.000194086, delta loss: 2.35086e-07
# epoch 500, loss: 0.000173828, delta loss: 2.00511e-07
# Training time: 274.5440
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000222518, delta loss: 7.05215e-07
#
# Propogate
#
# epoch 200, loss: 0.000259017, delta loss: 9.84379e-07
# epoch 300, loss: 0.000203705, delta loss: 4.54267e-07
# epoch 400, loss: 0.00017626, delta loss: 1.67871e-07
# epoch 500, loss: 0.000156125, delta loss: 2.93716e-07
# Training time: 291.7805
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000178669, delta loss: 3.31303e-07
# epoch 200, loss: 0.000153763, delta loss: 1.30982e-07
#
# Propogate
#
# epoch 300, loss: 0.000178171, delta loss: 6.42962e-07
# epoch 400, loss: 0.000145198, delta loss: 4.14613e-07
#
# Propogate
#
# epoch 500, loss: 0.000266324, delta loss: 5.36043e-06
# Training time: 309.6668
# Train L-BFGS:
# epoch 100, loss: 0.000159946, delta loss: 2.54833e-07
#
# Propogate
#
# epoch 200, loss: 0.000238249, delta loss: 1.72547e-05
# epoch 300, loss: 0.000139353, delta loss: 1.23051e-07
#
# Propogate
#
# epoch 400, loss: 0.00015053, delta loss: 1.76122e-07
#
# Propogate
#
# epoch 500, loss: 0.000167485, delta loss: 4.41985e-07
# Training time: 328.0269
# Train L-BFGS:
#
# Propogate
#
#
# Propogate
#
# epoch 100, loss: 0.000472355, delta loss: 1.03031e-05
# epoch 200, loss: 0.00017889, delta loss: 2.37342e-07
# epoch 300, loss: 0.000155369, delta loss: 1.64597e-07
#
# Propogate
#
# epoch 400, loss: 0.000164359, delta loss: 2.60567e-07
# epoch 500, loss: 0.000143895, delta loss: 1.62341e-07
# Training time: 347.4836
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000146298, delta loss: 1.43627e-07
#
# Propogate
#
#
# Propogate
#
# epoch 200, loss: 0.000404103, delta loss: 1.81996e-05
# epoch 300, loss: 0.000171399, delta loss: 4.27215e-07
# epoch 400, loss: 0.000149503, delta loss: 1.46421e-07
#
# Propogate
#
# epoch 500, loss: 0.000157836, delta loss: 5.25892e-07
# Training time: 367.0494
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000154592, delta loss: 2.46786e-07
# epoch 200, loss: 0.000133139, delta loss: 1.15091e-07
#
# Propogate
#
# epoch 300, loss: 0.000141639, delta loss: 1.20985e-07
#
# Propogate
#
# epoch 400, loss: 0.000147375, delta loss: 1.62792e-07
#
# Propogate
#
# epoch 500, loss: 0.000162273, delta loss: 8.09261e-07
# Training time: 386.8911
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000178397, delta loss: 2.67406e-07
# epoch 200, loss: 0.000153937, delta loss: 2.49711e-07
#
# Propogate
#
# epoch 300, loss: 0.000164324, delta loss: 5.65211e-07
# epoch 400, loss: 0.000138626, delta loss: 1.53203e-07
#
# Propogate
#
# epoch 500, loss: 0.000180544, delta loss: 1.61308e-06
# Training time: 406.7038
# Train L-BFGS:
# epoch 100, loss: 0.000141345, delta loss: 1.23269e-07
#
# Propogate
#
# epoch 200, loss: 0.000147404, delta loss: 1.27693e-07
#
# Propogate
#
# epoch 300, loss: 0.00015125, delta loss: 4.0092e-07
#
# Propogate
#
# epoch 400, loss: 0.000164624, delta loss: 3.70972e-07
#
# Propogate
#
# epoch 500, loss: 0.000169795, delta loss: 5.35802e-07
# Training time: 426.3215
# Train L-BFGS:
# epoch 100, loss: 0.000145122, delta loss: 1.54279e-07
#
# Propogate
#
#
# Propogate
#
# epoch 200, loss: 0.000420783, delta loss: 1.15189e-05
# epoch 300, loss: 0.000192791, delta loss: 5.13319e-07
# epoch 400, loss: 0.000160072, delta loss: 1.78436e-07
#
# Propogate
#
# epoch 500, loss: 0.00603439, delta loss: 0.000680621
# Training time: 447.2078
# Train L-BFGS:
# epoch 100, loss: 0.000173259, delta loss: 5.71614e-07
#
# Propogate
#
# epoch 200, loss: 0.000186521, delta loss: 6.00296e-07
# epoch 300, loss: 0.000154044, delta loss: 1.76849e-07
#
# Propogate
#
# epoch 400, loss: 0.000155117, delta loss: 2.09766e-07
#
# Propogate
#
#
# Propogate
#
# epoch 500, loss: 0.00029355, delta loss: 3.5711e-06
# Training time: 467.7970
# Train L-BFGS:
# epoch 100, loss: 0.000183986, delta loss: 3.25701e-07
#
# Propogate
#
# epoch 200, loss: 0.000223069, delta loss: 4.72923e-06
# epoch 300, loss: 0.000169552, delta loss: 2.47848e-07
#
# Propogate
#
# epoch 400, loss: 0.00018394, delta loss: 7.63437e-07
# epoch 500, loss: 0.000151293, delta loss: 1.39757e-07
# Training time: 488.2814
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.000179752, delta loss: 3.03102e-07
#
# Propogate
#
# epoch 200, loss: 0.000259306, delta loss: 3.68533e-06
# epoch 300, loss: 0.000178364, delta loss: 2.58384e-07
# epoch 400, loss: 0.000157762, delta loss: 1.60246e-07
#
# Propogate
#
#
# Propogate
#
#
# End Propogate
#
# epoch 500, loss: 0.000110196, delta loss: 4.80504e-08
# Training time: 507.7489
# Train L-BFGS:
# epoch 100, loss: 0.0001037, delta loss: 7.37055e-08
# epoch 200, loss: 9.74674e-05, delta loss: 7.12243e-08
# epoch 300, loss: 9.20898e-05, delta loss: 3.76458e-08
# epoch 400, loss: 8.8373e-05, delta loss: 3.10902e-08
# epoch 500, loss: 8.61425e-05, delta loss: 2.8107e-08
# Training time: 522.7157
# Train L-BFGS:
# epoch 100, loss: 8.39356e-05, delta loss: 2.62517e-08
# epoch 200, loss: 8.15556e-05, delta loss: 2.45127e-08
# epoch 300, loss: 7.97642e-05, delta loss: 2.63681e-08
#
# End Condition
#
# Training time: 534.0421
# No Residual set
# L2-error:  0.036211665062647454
