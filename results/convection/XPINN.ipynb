# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
# Add source and data file paths
import os
path = os.path.abspath(os.getcwd())
os.chdir("../..")
parent_path = os.path.abspath(os.getcwd())

import sys 
sys.path.insert(1, parent_path + '\\source')
sys.path.insert(2, parent_path + '\\data')

import numpy as np; import torch; import time

# Import source/helper functions
from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
pde_type = 'convection'
newParams = {}

#pde_type = 'new'
#newParams = {}; newParams['data'] = parent_path+'\\data\\convec_10.mat'; newParams['pde'] = 'u_t + 10*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 1; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
dirichlet_bc = 0 # Use Dirichlet boundary condtions based on reference solution (0 = no, 1 = yes), number of points will depend on reference solution not user-defined N_b
learned_weights = 0 
lambda_w = 100 # Weight applied to non PDE-reisudal loss terms

### Training data parameters
N_x = 100; N_t = 100; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 200 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 10; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 10 # Number of continuously training segments
causal_dS = 0 # Boolean for adding in intial dS segments causality or not (0 = no, 1 = yes)
stacked_tol = 1*10**(-7)

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['uavg', 'rc'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
#window_scheme = 'erf'
#scheme_parameters = (50, 10**(-8), 10**(-2), 1, 10**(-5)) 
window_scheme = 'none'
scheme_parameters = [2*10**(-1), 10**(-9), 1*10**(-2), 1]
# [(If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale; 
# If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance; 
# If 'causual_weights': epsilon), bound tolerance]

userPar = get_userPar(path, pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol, lambda_w, dirichlet_bc)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['animation'] = 0; # Boolean for showing/saving snapshots to make animation. If 0, it will just show/save the end of training
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'convection_XPINN' # Name of file to save training snapshots under
userPar['show_fig'] = 1; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
SEED = 0

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 0

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1
lbfgs_loops = 100
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 58.2741
# epoch 200, loss: 51.0024
# epoch 300, loss: 49.9163
# epoch 400, loss: 49.408
# epoch 500, loss: 49.0409
# Training time: 94.6571
# Train L-BFGS:
# epoch 100, loss: 47.7077, delta loss: 0.018116
# epoch 200, loss: 46.7655, delta loss: 0.00396347
# epoch 300, loss: 46.2561, delta loss: 0.0045166
# epoch 400, loss: 45.6245, delta loss: 0.00601578
# epoch 500, loss: 44.1526, delta loss: 0.0195198
# Training time: 195.4727
# Train L-BFGS:
# epoch 100, loss: 41.7662, delta loss: 0.0247421
# epoch 200, loss: 39.3091, delta loss: 0.0184937
# epoch 300, loss: 37.9178, delta loss: 0.0143089
# epoch 400, loss: 36.9261, delta loss: 0.0137329
# epoch 500, loss: 36.3417, delta loss: 0.00337982
# Training time: 301.1671
# Train L-BFGS:
# epoch 100, loss: 36.0159, delta loss: 0.0032959
# epoch 200, loss: 35.8092, delta loss: 0.00111008
# epoch 300, loss: 35.6771, delta loss: 0.00139999
# epoch 400, loss: 35.4869, delta loss: 0.00253677
# epoch 500, loss: 35.3097, delta loss: 0.00149918
# Training time: 406.2996
# Train L-BFGS:
# epoch 100, loss: 35.1565, delta loss: 0.00120926
# epoch 200, loss: 34.9466, delta loss: 0.00320435
# epoch 300, loss: 34.3392, delta loss: 0.00922775
# epoch 400, loss: 33.5579, delta loss: 0.0104141
# epoch 500, loss: 32.1328, delta loss: 0.0185547
# Training time: 509.5126
# Train L-BFGS:
# epoch 100, loss: 25.0315, delta loss: 0.0661411
# epoch 200, loss: 21.8946, delta loss: 0.0238895
# epoch 300, loss: 20.0314, delta loss: 0.00988579
# epoch 400, loss: 19.0889, delta loss: 0.0120335
# epoch 500, loss: 17.5425, delta loss: 0.0124454
# Training time: 608.8631
# Train L-BFGS:
# epoch 100, loss: 14.9478, delta loss: 0.0322075
# epoch 200, loss: 13.1694, delta loss: 0.00701714
# epoch 300, loss: 12.6476, delta loss: 0.00215244
# epoch 400, loss: 12.4464, delta loss: 0.00244045
# epoch 500, loss: 12.2437, delta loss: 0.001441
# Training time: 716.2928
# Train L-BFGS:
# epoch 100, loss: 12.1457, delta loss: 0.000801086
# epoch 200, loss: 12.0592, delta loss: 0.00078392
# epoch 300, loss: 11.9689, delta loss: 0.000905037
# epoch 400, loss: 11.8868, delta loss: 0.000757217
# epoch 500, loss: 11.8329, delta loss: 0.000308037
# Training time: 819.9174
# Train L-BFGS:
# epoch 100, loss: 11.805, delta loss: 0.000253677
# epoch 200, loss: 11.7854, delta loss: 0.000209808
# epoch 300, loss: 11.7588, delta loss: 0.000193596
# epoch 400, loss: 11.7273, delta loss: 0.000401497
# epoch 500, loss: 11.6877, delta loss: 0.000278473
# Training time: 922.5489
# epoch 200, loss: 11.2907, delta loss: 7.34329e-05
# epoch 300, loss: 11.2812, delta loss: 9.53674e-05
# epoch 400, loss: 11.2746, delta loss: 5.14984e-05
# epoch 500, loss: 11.2642, delta loss: 9.25064e-05
# Training time: 1883.9171
# Train L-BFGS:
# epoch 100, loss: 11.257, delta loss: 6.19888e-05
# epoch 200, loss: 11.2509, delta loss: 4.29153e-05
# epoch 300, loss: 11.2467, delta loss: 4.86374e-05
# epoch 400, loss: 11.2428, delta loss: 3.62396e-05
# epoch 500, loss: 11.2371, delta loss: 5.34058e-05
# Training time: 1989.5225
# Train L-BFGS:
# epoch 100, loss: 11.2304, delta loss: 6.86646e-05
# epoch 200, loss: 11.2171, delta loss: 0.00012207
# epoch 300, loss: 11.204, delta loss: 0.000107765
# epoch 400, loss: 11.189, delta loss: 8.39233e-05
# epoch 500, loss: 11.1805, delta loss: 8.01086e-05
# Training time: 2097.8897
# Train L-BFGS:
# epoch 100, loss: 11.1729, delta loss: 0.000165939
# epoch 200, loss: 11.1557, delta loss: 0.00014782
# epoch 300, loss: 11.1407, delta loss: 8.86917e-05
# epoch 400, loss: 11.118, delta loss: 0.00015831
# epoch 500, loss: 11.1053, delta loss: 0.000106812
# Training time: 2203.7787
# Train L-BFGS:
# epoch 100, loss: 11.0874, delta loss: 0.000380516
# epoch 200, loss: 11.0484, delta loss: 0.000770569
# epoch 300, loss: 10.9973, delta loss: 0.000396729
# epoch 400, loss: 10.9537, delta loss: 0.000552177
# epoch 500, loss: 10.8966, delta loss: 0.0012207
# Training time: 2305.3139
# Train L-BFGS:
# epoch 100, loss: 10.799, delta loss: 0.00080204
# epoch 200, loss: 10.6902, delta loss: 0.00169182
# epoch 300, loss: 10.5777, delta loss: 0.00176716
# epoch 400, loss: 10.471, delta loss: 0.000665665
# epoch 500, loss: 10.3738, delta loss: 0.000745773
# Training time: 2409.4400
# Train L-BFGS:
# epoch 100, loss: 10.3047, delta loss: 0.000921249
# epoch 200, loss: 10.2033, delta loss: 0.000495911
# epoch 300, loss: 10.1467, delta loss: 0.000821114
# epoch 400, loss: 10.0629, delta loss: 0.00117683
# epoch 500, loss: 9.98796, delta loss: 0.000352859
# Training time: 2513.0736
# Train L-BFGS:
# epoch 100, loss: 9.91198, delta loss: 0.000538826
# epoch 200, loss: 9.84124, delta loss: 0.000423431
# epoch 300, loss: 9.78826, delta loss: 0.000404358
# epoch 400, loss: 9.72679, delta loss: 0.000352859
# epoch 500, loss: 9.65527, delta loss: 0.000268936
# Training time: 2617.4191
# Train L-BFGS:
# epoch 100, loss: 9.61085, delta loss: 0.000394821
# epoch 200, loss: 9.56767, delta loss: 0.000425339
# epoch 300, loss: 9.51038, delta loss: 0.000312805
# epoch 400, loss: 9.4745, delta loss: 0.000551224
# epoch 500, loss: 9.43239, delta loss: 0.000648499
# Training time: 2721.2737
# Train L-BFGS:
# epoch 100, loss: 9.38048, delta loss: 0.000398636
# epoch 200, loss: 9.33492, delta loss: 0.000404358
# epoch 300, loss: 9.297, delta loss: 0.00045681
# epoch 400, loss: 9.24978, delta loss: 0.000288963
# epoch 500, loss: 9.21563, delta loss: 0.000331879
# Training time: 2829.1585
# Train L-BFGS:
# epoch 100, loss: 9.18565, delta loss: 0.000352859
# epoch 200, loss: 9.15991, delta loss: 0.00037384
# epoch 300, loss: 9.12655, delta loss: 0.000237465
# epoch 400, loss: 9.10359, delta loss: 0.000146866
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4e41bcd83710> in <module>
#       1 adam_loops = 1
#       2 lbfgs_loops = 100
# ----> 3 model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
#
# G:\My Drive\Research\Notebook files\dtPINN\source\misc_helper.py in training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
#     108         print('Train L-BFGS:')
#     109         start_time = time.time() # Track training time
# --> 110         optim_state_dict, optimizer, iterations, new_partition, end_condition = model.train_lbfgs(optim_state, optim_state_dict, optimizer)
#     111         elapsed = time.time() - start_time
#     112         train_time += elapsed
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in train_lbfgs(self, optim_state, optim_state_dict, optimizer)
#     457                 return self.prev_loss
#     458
# --> 459         optimizer.step(closure)
#     460
#     461         # Check for stacked decomp condition
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\optim\lbfgs.py in step(self, closure)
#     435                     # no use to re-evaluate that function here
#     436                     with torch.enable_grad():
# --> 437                         loss = float(closure())
#     438                     flat_grad = self._gather_flat_grad()
#     439                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in closure()
#     423                 iter_count += 1
#     424                 optimizer.zero_grad()
# --> 425                 bound_loss, init_loss, bc_loss, res_loss, inter_loss, weight_loss, window_vars = self.get_loss()
#     426                 loss = bound_loss + init_loss + bc_loss + res_loss + inter_loss + weight_loss
#     427
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in get_loss(self)
#     234
#     235                 ### Residual/collocation loss
# --> 236                 uf = self.forward(dnet, tf, xf, a())
#     237                 variables = self.get_partials(uf, tf, xf, 0)
#     238                 fu = self.PDE.PDE(variables)
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in forward(self, net, t, x, a)
#     141         else:
#     142             x = 2*((x - self.xmin)/(self.xmax - self.xmin))-1 # Normalize inputs to [-1,1] if there is no input encoding
# --> 143         return net(torch.cat((t, x), 1), a)[:,0].reshape((-1,1))
#     144
#     145     def exact_bc_encoding(self, x):
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in forward(self, x, a)
#      22     def forward(self, x, a):
#      23         for i in range(len(self.fc) - 1):
# ---> 24             x = self.fc[i](x)
#      25             if self.adaptive_activation == 1: # Use adaptive activation functions or not
#      26                 x = self.act(a*x)
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# ~\anaconda3\envs\ml_38\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:
