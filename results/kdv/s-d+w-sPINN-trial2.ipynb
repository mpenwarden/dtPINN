# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
# Add source and data file paths
import os
path = os.path.abspath(os.getcwd())
os.chdir("../..")
parent_path = os.path.abspath(os.getcwd())

import sys 
sys.path.insert(1, parent_path + '\\source')
sys.path.insert(2, parent_path + '\\data')

import numpy as np; import torch; import time

# Import source/helper functions
from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
pde_type = 'kdv'
newParams = {}

#pde_type = 'new'
#newParams = {}; newParams['data'] = parent_path+'\\data\\convec_10.mat'; newParams['pde'] = 'u_t + 10*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 1; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
dirichlet_bc = 0 # Use Dirichlet boundary condtions based on reference solution (0 = no, 1 = yes), number of points will depend on reference solution not user-defined N_b
learned_weights = 0 
lambda_w = 100 # Weight applied to non PDE-reisudal loss terms

### Training data parameters
N_x = 100; N_t = 100; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 200 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 10; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 1 # Number of continuously training segments
causal_dS = 1 # Boolean for adding in intial dS segments causality or not (0 = no, 1 = yes)
stacked_tol = 1*10**(-7)

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['u'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
window_scheme = 'uniform'
scheme_parameters = [2*10**(-2), 1*10**(-6), 2*10**(-2), 1, 0, 1, 0]
# [(If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale; 
# If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance; 
# If 'causual_weights': epsilon), bound tolerance]

userPar = get_userPar(path, pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol, lambda_w, dirichlet_bc)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['animation'] = 0; # Boolean for showing/saving snapshots to make animation. If 0, it will just show/save the end of training
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'KdV_s-d+w-s_1_trial2' # Name of file to save training snapshots under
userPar['show_fig'] = 1; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
userPar['log'] = 1; # Logs rel L2 error, runtime, loss over iterations, prediction, etc.
SEED = 1

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 1

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1
lbfgs_loops = 500
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 1.0132, delta loss: 0.00130284
# epoch 200, loss: 0.926224, delta loss: 0.0010941
# epoch 300, loss: 0.766255, delta loss: 0.00229019
# epoch 400, loss: 0.422891, delta loss: 0.00460765
# epoch 500, loss: 0.0525501, delta loss: 0.00144144
# Training time: 14.3395
# Train L-BFGS:
# epoch 100, loss: 0.00277879, delta loss: 2.30102e-05
# epoch 200, loss: 0.00130174, delta loss: 3.1693e-05
#
# Propogate
#
# epoch 300, loss: 0.00214709, delta loss: 1.28292e-05
# epoch 400, loss: 0.00127014, delta loss: 4.88455e-06
# epoch 500, loss: 0.000891408, delta loss: 1.38389e-06
# Training time: 35.9908
# Train L-BFGS:
# epoch 100, loss: 0.000696831, delta loss: 3.23134e-06
#
# Propogate
#
# epoch 200, loss: 0.00109271, delta loss: 1.90083e-06
# epoch 300, loss: 0.000411056, delta loss: 1.01565e-05
#
# Propogate
#
#
# Propogate
#
# epoch 400, loss: 0.00190122, delta loss: 1.47329e-05
# epoch 500, loss: 0.000583394, delta loss: 3.34956e-06
# Training time: 65.9154
# Train L-BFGS:
#
# Propogate
#
#
# End Propogate
#
# epoch 100, loss: 0.00026907, delta loss: 9.16567e-07
# epoch 200, loss: 0.000184255, delta loss: 7.48449e-07
# epoch 300, loss: 0.000137457, delta loss: 1.25932e-07
#
# New Partition
#
# Training time: 89.2467
# Train L-BFGS:
# epoch 100, loss: 0.0004464, delta loss: 1.06584e-06
#
# Propogate
#
# epoch 200, loss: 0.00179322, delta loss: 1.07067e-05
#
# Propogate
#
# epoch 300, loss: 0.00202993, delta loss: 6.49404e-05
# epoch 400, loss: 0.00112867, delta loss: 2.35543e-06
# epoch 500, loss: 0.000698235, delta loss: 1.99169e-06
# Training time: 112.7532
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.00124137, delta loss: 1.68232e-06
#
# Propogate
#
# epoch 200, loss: 0.00351701, delta loss: 3.72692e-05
# epoch 300, loss: 0.00214367, delta loss: 4.7884e-06
# epoch 400, loss: 0.00164295, delta loss: 8.38412e-06
# epoch 500, loss: 0.00131319, delta loss: 2.22819e-06
# Training time: 145.5256
# Train L-BFGS:
# epoch 100, loss: 0.00102105, delta loss: 1.3602e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 200, loss: 0.000789392, delta loss: 1.77778e-06
# epoch 300, loss: 0.00061196, delta loss: 1.98628e-06
# epoch 400, loss: 0.000477417, delta loss: 2.0045e-06
# epoch 500, loss: 0.000383481, delta loss: 7.86385e-07
# Training time: 178.8915
# Train L-BFGS:
# epoch 100, loss: 0.000341721, delta loss: 3.20113e-07
# epoch 200, loss: 0.000302851, delta loss: 1.80182e-07
# epoch 300, loss: 0.000265539, delta loss: 3.28204e-07
# epoch 400, loss: 0.000239442, delta loss: 2.61702e-07
#
# New Partition
#
# Training time: 210.6901
# Train L-BFGS:
# epoch 100, loss: 0.000815975, delta loss: 3.09519e-06
# epoch 200, loss: 0.00050473, delta loss: 1.24413e-06
#
# Propogate
#
# epoch 300, loss: 0.00178732, delta loss: 2.01568e-05
# epoch 400, loss: 0.00118015, delta loss: 1.2758e-06
#
# Propogate
#
# epoch 500, loss: 0.00288754, delta loss: 2.38726e-05
# Training time: 233.9627
# Train L-BFGS:
# epoch 100, loss: 0.00217168, delta loss: 6.63893e-06
# epoch 200, loss: 0.00164149, delta loss: 3.03646e-06
#
# Propogate
#
# epoch 300, loss: 0.00464173, delta loss: 3.38377e-05
# epoch 400, loss: 0.00345518, delta loss: 6.39982e-06
# epoch 500, loss: 0.00266932, delta loss: 7.14348e-06
# Training time: 264.1216
# Train L-BFGS:
# epoch 100, loss: 0.00188961, delta loss: 5.32111e-06
# epoch 200, loss: 0.00157087, delta loss: 1.50176e-06
#
# Propogate
#
# epoch 300, loss: 0.00360921, delta loss: 3.17353e-05
# epoch 400, loss: 0.00265089, delta loss: 4.53927e-06
# epoch 500, loss: 0.00231693, delta loss: 3.81935e-06
# Training time: 296.4418
# Train L-BFGS:
# epoch 100, loss: 0.00198131, delta loss: 3.97372e-06
# epoch 200, loss: 0.00163362, delta loss: 2.30933e-06
# epoch 300, loss: 0.00141785, delta loss: 2.49816e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 400, loss: 0.00127707, delta loss: 8.10134e-07
# epoch 500, loss: 0.00111412, delta loss: 9.45525e-07
# Training time: 329.5349
# Train L-BFGS:
# epoch 100, loss: 0.00103022, delta loss: 8.28644e-07
# epoch 200, loss: 0.000930165, delta loss: 1.21276e-06
# epoch 300, loss: 0.000816112, delta loss: 1.3528e-06
# epoch 400, loss: 0.000738696, delta loss: 5.71774e-07
# epoch 500, loss: 0.000639025, delta loss: 9.00531e-07
# Training time: 362.5498
# Train L-BFGS:
# epoch 100, loss: 0.000577181, delta loss: 1.00682e-06
# epoch 200, loss: 0.000521136, delta loss: 4.80562e-07
# epoch 300, loss: 0.000483503, delta loss: 4.14671e-07
#
# New Partition
#
# Training time: 389.4474
# Train L-BFGS:
# epoch 100, loss: 0.00107703, delta loss: 1.39853e-05
# epoch 200, loss: 0.000622646, delta loss: 9.74396e-07
#
# Propogate
#
# epoch 300, loss: 0.00217489, delta loss: 2.61259e-06
# epoch 400, loss: 0.00150868, delta loss: 2.29443e-06
# epoch 500, loss: 0.00126702, delta loss: 1.99105e-06
# Training time: 412.0717
# Train L-BFGS:
# epoch 100, loss: 0.000929881, delta loss: 2.15578e-06
#
# Propogate
#
# epoch 200, loss: 0.003683, delta loss: 0.000113324
# epoch 300, loss: 0.0020639, delta loss: 1.04432e-05
# epoch 400, loss: 0.00149041, delta loss: 3.24869e-06
# epoch 500, loss: 0.00112927, delta loss: 2.72342e-06
# Training time: 440.7627
# Train L-BFGS:
# epoch 100, loss: 0.000871258, delta loss: 2.07603e-06
#
# Propogate
#
# epoch 200, loss: 0.00194737, delta loss: 6.64615e-06
# epoch 300, loss: 0.00148854, delta loss: 2.21224e-06
# epoch 400, loss: 0.00123612, delta loss: 1.47207e-06
#
# Propogate
#
# epoch 500, loss: 0.00347535, delta loss: 2.77113e-05
# Training time: 471.1549
# Train L-BFGS:
# epoch 100, loss: 0.00258087, delta loss: 5.69015e-06
# epoch 200, loss: 0.00210593, delta loss: 3.54834e-06
# epoch 300, loss: 0.00173723, delta loss: 2.60479e-06
# epoch 400, loss: 0.001441, delta loss: 2.21853e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 500, loss: 0.00121181, delta loss: 1.39675e-06
# Training time: 503.5900
# Train L-BFGS:
# epoch 100, loss: 0.00109118, delta loss: 1.49605e-06
# epoch 200, loss: 0.000935852, delta loss: 1.273e-06
# epoch 300, loss: 0.000817275, delta loss: 7.83592e-07
# epoch 400, loss: 0.000718392, delta loss: 4.86092e-07
# epoch 500, loss: 0.000671654, delta loss: 6.13683e-07
# Training time: 535.6177
# Train L-BFGS:
# epoch 100, loss: 0.000627069, delta loss: 4.60888e-07
# epoch 200, loss: 0.000588482, delta loss: 4.15079e-07
#
# New Partition
#
# Training time: 556.0434
# Train L-BFGS:
# epoch 100, loss: 0.000473487, delta loss: 2.90931e-06
#
# Propogate
#
# epoch 200, loss: 0.00284324, delta loss: 3.9232e-05
# epoch 300, loss: 0.00125238, delta loss: 1.23346e-05
# epoch 400, loss: 0.000861437, delta loss: 2.04722e-06
# epoch 500, loss: 0.0006425, delta loss: 2.09449e-06
# Training time: 579.3426
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.00172779, delta loss: 1.21992e-05
# epoch 200, loss: 0.00110991, delta loss: 5.55452e-06
# epoch 300, loss: 0.000809599, delta loss: 3.50515e-06
# epoch 400, loss: 0.000583016, delta loss: 1.72987e-06
#
# Propogate
#
# epoch 500, loss: 0.00166415, delta loss: 1.87217e-05
# Training time: 608.8147
# Train L-BFGS:
# epoch 100, loss: 0.00105277, delta loss: 3.51481e-06
# epoch 200, loss: 0.000859989, delta loss: 1.01444e-06
#
# Propogate
#
#
# Propogate
#
#
# End Propogate
#
# epoch 300, loss: 0.00187008, delta loss: 4.01412e-06
# epoch 400, loss: 0.00154835, delta loss: 2.31178e-06
# epoch 500, loss: 0.00127049, delta loss: 2.83227e-06
# Training time: 640.8220
# Train L-BFGS:
# epoch 100, loss: 0.00108722, delta loss: 1.15461e-06
# epoch 200, loss: 0.000935829, delta loss: 1.25304e-06
# epoch 300, loss: 0.00083502, delta loss: 4.62693e-07
# epoch 400, loss: 0.000773934, delta loss: 8.85397e-07
# epoch 500, loss: 0.000724353, delta loss: 5.10772e-07
# Training time: 673.9342
# Train L-BFGS:
# epoch 100, loss: 0.000665317, delta loss: 2.90398e-07
# epoch 200, loss: 0.000623286, delta loss: 6.4302e-07
# epoch 300, loss: 0.000566497, delta loss: 6.8004e-07
# epoch 400, loss: 0.000510893, delta loss: 8.9471e-07
# epoch 500, loss: 0.000449314, delta loss: 4.25644e-07
# Training time: 707.1006
# Train L-BFGS:
# epoch 100, loss: 0.000406433, delta loss: 3.92698e-07
# epoch 200, loss: 0.00035054, delta loss: 4.82425e-07
# epoch 300, loss: 0.000308315, delta loss: 3.34752e-07
#
# New Partition
#
# Training time: 735.3974
# Train L-BFGS:
# epoch 100, loss: 0.000564725, delta loss: 1.18717e-05
#
# Propogate
#
# epoch 200, loss: 0.00175193, delta loss: 2.81975e-05
# epoch 300, loss: 0.00078686, delta loss: 2.76353e-06
# epoch 400, loss: 0.000524842, delta loss: 2.52895e-06
#
# Propogate
#
# Training time: 756.3224
# Train L-BFGS:
# epoch 100, loss: 0.00139962, delta loss: 8.33464e-06
# epoch 200, loss: 0.000880288, delta loss: 5.66978e-06
#
# Propogate
#
# epoch 300, loss: 0.632462, delta loss: 0.0963483
# epoch 400, loss: 0.00258815, delta loss: 5.22761e-05
# epoch 500, loss: 0.00101666, delta loss: 2.05624e-06
# Training time: 786.4361
# Train L-BFGS:
# epoch 100, loss: 0.000735119, delta loss: 2.62429e-06
#
# Propogate
#
# epoch 200, loss: 0.0015971, delta loss: 1.90027e-05
# epoch 300, loss: 0.00104989, delta loss: 4.21528e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 400, loss: 0.000854504, delta loss: 1.2134e-06
# epoch 500, loss: 0.00075841, delta loss: 1.4024e-06
# Training time: 819.2629
# Train L-BFGS:
# epoch 100, loss: 0.000626504, delta loss: 7.63161e-07
# epoch 200, loss: 0.000558417, delta loss: 6.00703e-07
# epoch 300, loss: 0.000475767, delta loss: 9.18575e-07
# epoch 400, loss: 0.000413711, delta loss: 3.44939e-07
#
# New Partition
#
# Training time: 849.5253
# Train L-BFGS:
# epoch 100, loss: 0.00140818, delta loss: 1.42258e-05
# epoch 200, loss: 0.000519837, delta loss: 4.18635e-06
#
# Propogate
#
# epoch 300, loss: 0.00208106, delta loss: 2.36365e-05
# epoch 400, loss: 0.000973099, delta loss: 2.3687e-06
# epoch 500, loss: 0.000587445, delta loss: 4.76424e-06
# Training time: 872.1740
# Train L-BFGS:
#
# Propogate
#
#
# Propogate
#
# epoch 100, loss: 0.00539098, delta loss: 0.000133639
# epoch 200, loss: 0.00172362, delta loss: 8.62859e-06
# epoch 300, loss: 0.00115469, delta loss: 1.54297e-06
#
# Propogate
#
# epoch 400, loss: 0.00213178, delta loss: 3.95658e-05
# epoch 500, loss: 0.00132533, delta loss: 4.7239e-06
# Training time: 902.9722
# Train L-BFGS:
# epoch 100, loss: 0.0010106, delta loss: 2.36172e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 200, loss: 0.000848287, delta loss: 1.46718e-06
# epoch 300, loss: 0.000741274, delta loss: 8.23115e-07
# epoch 400, loss: 0.000647276, delta loss: 9.86853e-07
#
# New Partition
#
# Training time: 935.8195
# Train L-BFGS:
# epoch 100, loss: 0.000815327, delta loss: 4.94334e-06
#
# Propogate
#
# epoch 200, loss: 0.00214287, delta loss: 6.76159e-05
# epoch 300, loss: 0.0010203, delta loss: 5.40668e-06
# epoch 400, loss: 0.000567533, delta loss: 2.22115e-06
#
# Propogate
#
# epoch 500, loss: 0.000941888, delta loss: 3.32826e-06
# Training time: 957.4917
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.0028645, delta loss: 1.08436e-05
# epoch 200, loss: 0.00122877, delta loss: 5.94044e-06
# epoch 300, loss: 0.000932744, delta loss: 2.47586e-06
#
# Propogate
#
# epoch 400, loss: 0.00173453, delta loss: 1.29559e-05
#
# Propogate
#
#
# End Propogate
#
# epoch 500, loss: 0.00118192, delta loss: 1.16171e-06
# Training time: 988.9118
# Train L-BFGS:
# epoch 100, loss: 0.000982724, delta loss: 7.20844e-07
# epoch 200, loss: 0.000902168, delta loss: 6.78061e-07
# epoch 300, loss: 0.000818202, delta loss: 9.62347e-07
# epoch 400, loss: 0.000735536, delta loss: 1.07137e-06
# epoch 500, loss: 0.000657059, delta loss: 5.40866e-07
# Training time: 1021.5836
# Train L-BFGS:
# epoch 100, loss: 0.000594282, delta loss: 5.04486e-07
# epoch 200, loss: 0.000522621, delta loss: 8.97504e-07
# epoch 300, loss: 0.000444742, delta loss: 1.10484e-06
#
# New Partition
#
# Training time: 1050.1758
# Train L-BFGS:
# epoch 100, loss: 0.000406394, delta loss: 4.40565e-06
#
# Propogate
#
# epoch 200, loss: 0.00251206, delta loss: 0.000218129
# epoch 300, loss: 0.000616993, delta loss: 3.23536e-06
#
# Propogate
#
# epoch 400, loss: 0.00112649, delta loss: 1.1959e-05
# epoch 500, loss: 0.000478624, delta loss: 1.79393e-06
# Training time: 1074.7549
# Train L-BFGS:
#
# Propogate
#
# epoch 100, loss: 0.00139455, delta loss: 9.0528e-06
# epoch 200, loss: 0.000808504, delta loss: 4.35504e-06
#
# Propogate
#
# epoch 300, loss: 0.00124756, delta loss: 5.91401e-06
# epoch 400, loss: 0.000942036, delta loss: 2.33238e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 500, loss: 0.000683076, delta loss: 2.13098e-06
# Training time: 1107.8818
# Train L-BFGS:
# epoch 100, loss: 0.000511294, delta loss: 1.37236e-06
# epoch 200, loss: 0.000412522, delta loss: 1.1489e-06
# epoch 300, loss: 0.000360248, delta loss: 3.50352e-07
# epoch 400, loss: 0.000319517, delta loss: 3.04513e-07
# epoch 500, loss: 0.000277435, delta loss: 3.22121e-07
# Training time: 1141.8831
# Train L-BFGS:
# epoch 100, loss: 0.000259001, delta loss: 1.023e-07
#
# New Partition
#
# Training time: 1154.6294
# Train L-BFGS:
# epoch 100, loss: 0.000946133, delta loss: 7.52823e-06
# epoch 200, loss: 0.000453804, delta loss: 1.07495e-06
#
# Propogate
#
# epoch 300, loss: 0.00130839, delta loss: 1.12168e-05
# epoch 400, loss: 0.000790506, delta loss: 4.48473e-06
#
# Propogate
#
# epoch 500, loss: 0.0019519, delta loss: 1.9734e-05
# Training time: 1177.8416
# Train L-BFGS:
# epoch 100, loss: 0.00118004, delta loss: 3.01306e-06
# epoch 200, loss: 0.00077258, delta loss: 4.63706e-06
#
# Propogate
#
# epoch 300, loss: 0.00217503, delta loss: 3.41709e-05
# epoch 400, loss: 0.0011496, delta loss: 2.19815e-06
#
# Propogate
#
# epoch 500, loss: 0.00168787, delta loss: 3.96359e-06
# Training time: 1208.9568
# Train L-BFGS:
# epoch 100, loss: 0.00117297, delta loss: 4.50539e-06
# epoch 200, loss: 0.000883613, delta loss: 2.63989e-06
#
# Propogate
#
#
# End Propogate
#
# epoch 300, loss: 0.000711394, delta loss: 1.00798e-06
# epoch 400, loss: 0.000592802, delta loss: 1.09966e-06
# epoch 500, loss: 0.000503339, delta loss: 5.46628e-07
# Training time: 1242.8536
# Train L-BFGS:
# epoch 100, loss: 0.000442621, delta loss: 3.01661e-07
# epoch 200, loss: 0.000408762, delta loss: 3.45579e-07
# epoch 300, loss: 0.000373275, delta loss: 1.56317e-07
# epoch 400, loss: 0.000348619, delta loss: 4.65254e-07
#
# End Condition
#
# Training time: 1275.0017
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d6dc1438cd24> in <module>
#       1 adam_loops = 1
#       2 lbfgs_loops = 500
# ----> 3 model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
#
# G:\My Drive\Research\Notebook files\dtPINN\source\misc_helper.py in training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
#     146
#     147     if (userPar['save_fig'] == 1 or userPar['show_fig'] == 1): # Only show/save at the end of training (saves a lot of time if animation = 0)
# --> 148         l2_error, t_decomp, x_decomp, u_test_decomp, u_pred_decomp, epoch_list, loss_list = final_plot(userPar, dataPar, model, epoch_list, epoch_record_list, l2_error_list)
#     149
#     150         if userPar['log'] == 1:
#
# G:\My Drive\Research\Notebook files\dtPINN\source\plot_helper.py in final_plot(userPar, dataPar, model, epoch_list, epoch_record_list, l2_error_list)
#     295     ### dtPINN PREDICTION
#     296     if userPar['window_scheme'] != 'none':
# --> 297         u_pred, res, t_decomp_res, x_decomp_res, u_decomp_test, t_decomp_test, x_decomp_test = model.predict(u_decomp_test, t_decomp_test, x_decomp_test, return_residual)
#     298     else:
#     299         u_pred, res = model.predict(u_decomp_test, t_decomp_test, x_decomp_test, return_residual)
#
# G:\My Drive\Research\Notebook files\dtPINN\source\neuralNetwork_helper.py in predict(self, u_decomp_test, t_decomp_test, x_decomp_test, return_residual)
#     562                         if self.window_scheme != 'causal':
#     563                             res_weights = self.window_sweep.get_weights(t_res, u_res, res) # Get weights (need fu in case causal weights are used)
# --> 564                             res_out.append((res*res_weights).detach()); t_res_out.append(t_res.detach().numpy()); x_res_out.append(x_res.detach().numpy())
#     565                         else:
#     566                             res_out.append((res).detach()); t_res_out.append(t_res.detach().numpy()); x_res_out.append(x_res.detach().numpy())
#
# TypeError: only integer tensors of a single element can be converted to an index
