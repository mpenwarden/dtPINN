# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
# Add source and data file paths
import os
path = os.path.abspath(os.getcwd())
os.chdir("..")
parent_path = os.path.abspath(os.getcwd())

import sys 
sys.path.insert(1, parent_path + '\\source')
sys.path.insert(2, parent_path + '\\data')

import numpy as np; import torch; import time

from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif, load_log
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
### Use data and automatically define PINN PDE residuals from pre-defined problem (i.e. 'convection', 'allen-cahn', or 'kdv' in paper)
#pde_type = 'convection'
#newParams = {}

### Choose to solve new problem. First generate data using a modified MATLAB chebfun solver in the DATA folder and then define the PDE problem here. 
pde_type = 'new'
newParams = {}; newParams['data'] = parent_path+'\\data\\convection.mat'; newParams['pde'] = 'u_t + 30*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 1; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
dirichlet_bc = 0 # Use Dirichlet boundary condtions based on reference solution (0 = no, 1 = yes), number of points will depend on reference solution not user-defined N_b
learned_weights = 0 
lambda_w = 100 # Weight applied to non PDE-reisudal loss terms

### Training data parameters
N_x = 100; N_t = 100; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 400 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 10; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 1 # Number of continuously training segments
causal_dS = 1 # Boolean for adding in intial dS segments causality or not (0 = no, 1 = yes)
stacked_tol = 1*10**(-7)

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['u'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
window_scheme = 'none'
scheme_parameters = [1*10**(-1), 10**(-9), 1*10**(-1), 1]
# [(If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale; 
# If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance; 
# If 'causual_weights': epsilon), bound tolerance]

userPar = get_userPar(path, pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol, lambda_w, dirichlet_bc)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['animation'] = 1; # Boolean for showing/saving snapshots to make animation. If 0, it will just show/save the end of training
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'convection_example' # Name of file to save training snapshots under
userPar['show_fig'] = 0; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
userPar['log'] = 1
SEED = 0

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 0

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1 # Iterations per loop defined in prior adam_params
lbfgs_loops = 100 # Iterations per loop defined in prior lbfgs_params
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 44.7223, delta loss: 0.00350189
# epoch 200, loss: 44.1791, delta loss: 0.00947571
# epoch 300, loss: 41.0029, delta loss: 0.0839996
# epoch 400, loss: 30.7763, delta loss: 0.0245705
# epoch 500, loss: 16.3747, delta loss: 0.56979
# Training time: 5.0324
# L2-error:  0.6050262812281548
# Train L-BFGS:
# epoch 100, loss: 1.33421, delta loss: 0.042225
# epoch 200, loss: 0.257225, delta loss: 0.00178388
# epoch 300, loss: 0.109989, delta loss: 0.000560105
# epoch 400, loss: 0.0394998, delta loss: 0.000408709
# epoch 500, loss: 0.0161702, delta loss: 0.000189224
# Training time: 14.3314
# L2-error:  0.007894622646264143
# Train L-BFGS:
# epoch 100, loss: 0.0107845, delta loss: 2.71155e-05
# epoch 200, loss: 0.00713422, delta loss: 2.10814e-05
# epoch 300, loss: 0.00536006, delta loss: 1.4252e-05
# epoch 400, loss: 0.00457495, delta loss: 6.63241e-06
# epoch 500, loss: 0.00380846, delta loss: 9.72021e-06
# Training time: 24.2236
# L2-error:  0.0034568692801195053
# Train L-BFGS:
# epoch 100, loss: 0.00331824, delta loss: 6.3132e-06
#
# New Partition
#
# Training time: 219.5367
# L2-error:  0.2598015206527602
# Train L-BFGS:
# epoch 100, loss: 0.703245, delta loss: 0.0217997
# epoch 200, loss: 0.0800459, delta loss: 0.00106908
# epoch 300, loss: 0.0260078, delta loss: 0.0002764
# epoch 400, loss: 0.0113143, delta loss: 9.09576e-05
# epoch 500, loss: 0.00522265, delta loss: 1.72984e-05
# Training time: 230.2245
# L2-error:  0.005420463380956783
# Train L-BFGS:
# epoch 100, loss: 0.00397685, delta loss: 9.69181e-06
# epoch 200, loss: 0.00291268, delta loss: 5.76419e-06
# epoch 300, loss: 0.00223446, delta loss: 3.06428e-06
# epoch 400, loss: 0.00171853, delta loss: 3.58233e-06
# epoch 500, loss: 0.00140757, delta loss: 2.1013e-06
# Training time: 241.5146
# L2-error:  0.005099257971953508
# Train L-BFGS:
# epoch 100, loss: 0.00122138, delta loss: 2.25729e-06
# epoch 200, loss: 0.000949233, delta loss: 2.68634e-06
# epoch 300, loss: 0.00084828, delta loss: 1.17434e-06
# epoch 400, loss: 0.000770037, delta loss: 8.02567e-07
# epoch 500, loss: 0.000716195, delta loss: 7.98027e-07
# Training time: 252.5091
# L2-error:  0.004995139650879829
# Train L-BFGS:
# epoch 100, loss: 0.000622367, delta loss: 4.66767e-07
# epoch 200, loss: 0.000547919, delta loss: 5.95697e-07
# epoch 300, loss: 0.000496441, delta loss: 6.51984e-07
# epoch 400, loss: 0.000451234, delta loss: 3.43367e-07
# epoch 500, loss: 0.000397293, delta loss: 4.26196e-07
# Training time: 263.6769
# L2-error:  0.004867267722366529
# Train L-BFGS:
# epoch 100, loss: 0.000351363, delta loss: 2.72237e-07
#
# New Partition
#
# Training time: 270.4603
# L2-error:  0.2684944485961458
# Train L-BFGS:
# epoch 100, loss: 1.15861, delta loss: 0.0766772
# epoch 200, loss: 0.0977174, delta loss: 0.0023191
# epoch 300, loss: 0.0204065, delta loss: 0.000270437
# epoch 400, loss: 0.010258, delta loss: 9.54075e-05
# epoch 500, loss: 0.00664372, delta loss: 1.68378e-05
# Training time: 281.2635
# L2-error:  0.005541560680673608
# Train L-BFGS:
# epoch 100, loss: 0.0045718, delta loss: 1.50474e-05
# epoch 200, loss: 0.00346723, delta loss: 7.63149e-06
# epoch 300, loss: 0.0026541, delta loss: 7.11367e-06
# epoch 400, loss: 0.00187125, delta loss: 4.89247e-06
# epoch 500, loss: 0.00124356, delta loss: 2.12737e-06
# Training time: 292.5157
# L2-error:  0.005273022155495559
# Train L-BFGS:
# epoch 100, loss: 0.00102879, delta loss: 2.18384e-06
# epoch 200, loss: 0.000849567, delta loss: 1.62114e-06
# epoch 300, loss: 0.000702444, delta loss: 8.26549e-07
#
# New Partition
#
# Training time: 302.0157
# L2-error:  0.27135387148029977
# Train L-BFGS:
# epoch 100, loss: 4.61474, delta loss: 0.197687
# epoch 200, loss: 0.236373, delta loss: 0.00338936
# epoch 400, loss: 0.00185453, delta loss: 1.35438e-06
# epoch 500, loss: 0.00168951, delta loss: 1.5212e-06
# Training time: 401.6604
# L2-error:  0.0054700845639267725
# Train L-BFGS:
# epoch 100, loss: 0.00148803, delta loss: 1.66928e-06
# epoch 200, loss: 0.00139694, delta loss: 5.75325e-07
# epoch 300, loss: 0.00128857, delta loss: 5.40167e-07
# epoch 400, loss: 0.00118806, delta loss: 1.29174e-06
# epoch 500, loss: 0.00105026, delta loss: 1.41829e-06
# Training time: 412.7754
# L2-error:  0.0053698461720522285
# Train L-BFGS:
# epoch 100, loss: 0.00091243, delta loss: 1.2485e-06
# epoch 200, loss: 0.000814306, delta loss: 6.74627e-07
# epoch 300, loss: 0.000753124, delta loss: 3.81726e-07
# epoch 400, loss: 0.000723901, delta loss: 2.7864e-07
#
# New Partition
#
# Training time: 423.7805
# L2-error:  0.20000660886721822
# Train L-BFGS:
# epoch 100, loss: 10.0724, delta loss: 0.221908
# epoch 200, loss: 0.848867, delta loss: 0.0243082
# epoch 300, loss: 0.230291, delta loss: 0.00132962
# epoch 400, loss: 0.110117, delta loss: 0.000405863
# epoch 500, loss: 0.0519269, delta loss: 0.000215545
# Training time: 434.9771
# L2-error:  0.005719475204423971
# Train L-BFGS:
# epoch 100, loss: 0.0365158, delta loss: 6.22086e-05
# epoch 200, loss: 0.0287845, delta loss: 2.68817e-05
# epoch 300, loss: 0.0215953, delta loss: 7.22688e-05
# epoch 400, loss: 0.0133679, delta loss: 5.04404e-05
# epoch 500, loss: 0.00969448, delta loss: 1.90539e-05
# Training time: 446.5470
# L2-error:  0.005469596610097611
# Train L-BFGS:
# epoch 100, loss: 0.00828847, delta loss: 1.9135e-05
# epoch 200, loss: 0.00634933, delta loss: 4.04799e-06
# epoch 300, loss: 0.00557505, delta loss: 7.59633e-06
# epoch 400, loss: 0.00470132, delta loss: 8.50204e-06
# epoch 500, loss: 0.00415353, delta loss: 3.25125e-06
# Training time: 457.7331
# L2-error:  0.00541861898999661
# Train L-BFGS:
# epoch 100, loss: 0.0036464, delta loss: 8.11648e-07
# epoch 200, loss: 0.00338565, delta loss: 5.24661e-06
# epoch 300, loss: 0.0031326, delta loss: 8.39122e-07
# epoch 400, loss: 0.00289421, delta loss: 2.81609e-06
# epoch 500, loss: 0.00269312, delta loss: 1.74413e-06
# Training time: 469.6074
# L2-error:  0.005445393718751615
# Train L-BFGS:
# epoch 100, loss: 0.00244001, delta loss: 5.3551e-07
# epoch 200, loss: 0.00225449, delta loss: 1.56066e-06
# epoch 300, loss: 0.00217915, delta loss: 8.14674e-07
# epoch 400, loss: 0.00205892, delta loss: 8.26316e-07
# epoch 500, loss: 0.00197182, delta loss: 7.25733e-07
# Training time: 481.1648
# L2-error:  0.0054040769440785895
# Train L-BFGS:
# epoch 100, loss: 0.00187475, delta loss: 5.10714e-07
# epoch 200, loss: 0.00181603, delta loss: 4.7381e-07
# epoch 300, loss: 0.00163558, delta loss: 2.09431e-06
# epoch 400, loss: 0.00156104, delta loss: 4.57745e-07
# epoch 500, loss: 0.00150577, delta loss: 5.72647e-07
# Training time: 491.6727
# L2-error:  0.00541041934206081
# Train L-BFGS:
# epoch 100, loss: 0.00142977, delta loss: 8.00937e-07
# epoch 200, loss: 0.00135906, delta loss: 9.23174e-07
# epoch 300, loss: 0.00122049, delta loss: 1.99478e-06
# epoch 400, loss: 0.00113249, delta loss: 6.76839e-07
# epoch 500, loss: 0.00105015, delta loss: 1.40234e-06
# Training time: 503.0226
# L2-error:  0.00541323690021601
# Train L-BFGS:
# epoch 100, loss: 0.000950088, delta loss: 6.20377e-07
# epoch 200, loss: 0.000887253, delta loss: 2.93425e-07
# epoch 300, loss: 0.000816868, delta loss: 3.30037e-07
# epoch 400, loss: 0.000776828, delta loss: 4.49247e-07
# epoch 500, loss: 0.000744085, delta loss: 2.7963e-07
# Training time: 513.8277
# L2-error:  0.0054058955140793424
# Train L-BFGS:
#
# New Partition
#
# Training time: 519.3631
# L2-error:  0.278545872395009
# Train L-BFGS:
# epoch 100, loss: 13.2498, delta loss: 0.1423
# epoch 200, loss: 0.96769, delta loss: 0.0114247
# epoch 300, loss: 0.351282, delta loss: 0.00294471
# epoch 400, loss: 0.137254, delta loss: 0.000631317
# epoch 500, loss: 0.060778, delta loss: 0.000250272
# Training time: 530.4532
# L2-error:  0.007697509446547704
# Train L-BFGS:
# epoch 100, loss: 0.0329252, delta loss: 0.000306923
# epoch 200, loss: 0.0198169, delta loss: 4.72628e-05
# epoch 300, loss: 0.0154702, delta loss: 2.38176e-05
# epoch 400, loss: 0.0119703, delta loss: 6.53695e-06
# epoch 500, loss: 0.0101655, delta loss: 2.53916e-05
# Training time: 541.0509
# L2-error:  0.00575932829225436
# Train L-BFGS:
# epoch 100, loss: 0.00796421, delta loss: 2.08952e-05
# epoch 200, loss: 0.00663431, delta loss: 1.17454e-05
# epoch 300, loss: 0.00567888, delta loss: 1.07964e-05
# epoch 400, loss: 0.0047164, delta loss: 1.08853e-05
# epoch 500, loss: 0.00395532, delta loss: 7.5018e-06
# Training time: 552.6660
# L2-error:  0.005503223087987332
# Train L-BFGS:
# epoch 100, loss: 0.00305437, delta loss: 1.40697e-05
# epoch 200, loss: 0.00242925, delta loss: 2.10595e-06
# epoch 300, loss: 0.0022087, delta loss: 1.41934e-06
# epoch 400, loss: 0.00203658, delta loss: 3.66662e-06
# epoch 500, loss: 0.0018048, delta loss: 2.71481e-06
# Training time: 564.1629
# L2-error:  0.005471334221489504
# Train L-BFGS:
#
# End Condition
#
# Training time: 570.2901
# L2-error:  0.006280146170693875
# L2-error:  0.006280146170693875

# %% [markdown]
# ### Step 3.4: Make animation if figures were saved or load run log

# %%
if userPar['save_fig'] == 1:
    make_gif(userPar)
    
if userPar['log'] == 1:
    log = load_log(userPar)
