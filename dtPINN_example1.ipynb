# %% [markdown]
# ### Step 0: Get packages and helper functions

# %%
import numpy as np; import torch; import time

from misc_helper import combine_layers, get_dt, get_userPar, training_loop, make_gif
from plot_helper import reference_plot, sample_plot
from trainingData_helper import generate_trainData
from windowSweep_helper import window_sweep_class
from pde_helper import PDE_class
from neuralNetwork_helper import Net, activation_func_a, weight_class, dtPINN

# %% [markdown]
# ## Step 1: Define PDE problem and visualize

# %%
pde_type = 'convection'
newParams = {}

#pde_type = 'new'
#newParams = {}; newParams['data'] = path+'\\data\\convec_10.mat'; newParams['pde'] = 'u_t + 10*u_x'; newParams['IC'] = 'np.sin(x)';

PDE = PDE_class(pde_type, newParams)
dataPar = PDE.data()

# Reference solution
reference_plot(dataPar)

# %% [markdown]
# ## Step 2: dtPINN user settings

# %%
### Neural network parameters
input_encoding = 1 # Boolean for encode input to enforce exact boundary condtions
M = 1; L = get_dt(dataPar['xmin'], dataPar['xmax'], 1) # Hyperparameters for exact BC encoding, not used if turned off
hidden_layers = [50, 50, 50, 50]; layers = combine_layers(input_encoding, M, hidden_layers) # PINN layers
# Note Adam and L-BFGS epoch/iterations are per frame for generating animations, the total amount is multiplied by the training loops defined below
# Will be cutoff early if a new network is added since optimizer needs to be reset via this control loop
adam_params = [500, 0.001] # Optimization Hyperparameters for Adam [epochs, learning rate]
lbfgs_params = [0.1, 500, None, -1, -1, 50] # Optimization Hyperparameters for LBFGS [learning rate, max iterations, max evaluations, tolerance gradient, tolerance change, history size]
adaptive_activation = 0 # Adaptive activation functions in NN
learned_weights = 0 

### Training data parameters
N_x = 100; N_t = 100; N_f = N_x*N_t # Number of collocation points in the ENTIRE domian (pre subdomain partitioning)
N_0 = 200 # Number of initial condtion points in the ENTIRE domain
N_b = 400 # Number of boundary condtion points in the ENTIRE domain
N_i = N_0 # Number of interface continuity points for each interface (total = N_i*(n-1))
collocation_sampling = 'lhs' # Latin-hypercube or grid sampling

### From Algorithm 1 in paper
## 1. Choose stacked-decomposition parameters [n, dS, adaptive dt]
num_partitions = 10; dt = get_dt(dataPar['tmin'], dataPar['tmax'], num_partitions) # Number of time-slabs in domain (1 = PINN) and dt derived from number and t-domain; 
dS = 1 # 
causal_dS = 1 #
stacked_tol = 1*10**(-7)
#adaptive_dt = 0 # Boolean [0 = off, 1 = on]

## 2. Choose interface conditions [residual continuity, Cp continuity, other]
interface_condition = ['u'] # List of interface condtions to add (u = solution continuity, uavg = average solution continuity, residual = minimize residuals, rc = minimize residual continuity)
# [xPINN = 'uavg' + 'rc', C^p continuity = 'u' for first-order systems]

## 3. Choose transfer learning parameters [number of layers, trainability of layers]
# If all layers that are transfered and kept learnable = 'fine-tuning'
# If some layers that are transfered and made unlearnable = 'transfer learning'
layer_transfer = [1, 1, 1, 1, 1] # Boolean mask to transfer weights and bias (length = len(layers) - 1)
layer_trainability = [1, 1, 1, 1, 1] # Boolean mask to make layers continue to be learnable or not (length = len(layers) - 1)

## 4. Choose window-sweeping parameters [weighting scheme, scheme hyperparameters]
#window_scheme = 'erf'
#scheme_parameters = (50, 10**(-8), 10**(-2), 1, 10**(-5)) 
window_scheme = 'none'
scheme_parameters = [1*10**(-1), 10**(-9), 1*10**(-1), 1]
# [(If 'none': , If 'uniform' or 'linear': width, propogate loss tolerance, dt, scale; If 'erf': sharpness, propogate loss tolerance, dt, scale, set cutoff tolerance; If 'causual_weights': epsilon), bound tolerance]

userPar = get_userPar(pde_type, input_encoding, M, L, layers, adam_params, lbfgs_params, adaptive_activation, learned_weights, N_x, N_t, N_f, N_0, N_b, N_i, collocation_sampling,\
                     num_partitions, dt, dS, causal_dS, interface_condition, layer_transfer, layer_trainability, window_scheme, scheme_parameters, PDE, stacked_tol)

# %% [markdown]
# ### Step 2.1: Generate and visualize training data

# %%
dataPar = generate_trainData(dataPar, userPar)
sample_plot(dataPar, userPar)

# %% [markdown]
# ## Step 3: Train model and visualize

# %% [markdown]
# ### Step 3.1: Define training and visualization parameters

# %%
### Training visualization parameters
userPar['save_fig'] = 1; # Save training figures
userPar['model_name'] = 'convection_test' # Name of file to save training snapshots under
userPar['show_fig'] = 0; # Display training figures
userPar['verbose'] = 1 # Print out various training varibles at train time such as loss and iterations
SEED = 0

# %% [markdown]
# ### Step 3.2: Initalize the model

# %%
print('SEED:', SEED); torch.manual_seed(SEED); np.random.seed(SEED);
model = dtPINN(dataPar, userPar)
# Out:
# SEED: 0

# %% [markdown]
# ### Step 3.3: Train the model

# %%
adam_loops = 1
lbfgs_loops = 100
model = training_loop(userPar, dataPar, model, adam_loops, lbfgs_loops)
# Out:
# dtPINN
# Train Adam:
# epoch 100, loss: 44.7178
# epoch 200, loss: 44.1708
# epoch 300, loss: 40.9497
# epoch 400, loss: 30.4743
# epoch 500, loss: 17.7102
# Training time: 5.9801
# L2-error:  0.6397201409452968
# Train L-BFGS:
# epoch 100, loss: 2.17876, delta loss: 0.0477417
# epoch 200, loss: 0.278453, delta loss: 0.00398332
# epoch 300, loss: 0.0482263, delta loss: 0.000597421
# epoch 400, loss: 0.0305978, delta loss: 5.57676e-05
# epoch 500, loss: 0.021182, delta loss: 0.000186862
# Training time: 18.4913
# L2-error:  0.00658415380871157
# Train L-BFGS:
# epoch 100, loss: 0.0130363, delta loss: 5.56456e-05
# epoch 200, loss: 0.00937941, delta loss: 1.67834e-05
# epoch 300, loss: 0.0073242, delta loss: 2.36542e-05
# epoch 400, loss: 0.00629521, delta loss: 7.00215e-06
# epoch 500, loss: 0.00506543, delta loss: 4.07547e-06
# Training time: 32.0462
# L2-error:  0.002976756884133529
# Train L-BFGS:
# epoch 100, loss: 0.00427891, delta loss: 4.58118e-06
# epoch 200, loss: 0.00350959, delta loss: 7.98074e-06
# epoch 300, loss: 0.00287477, delta loss: 4.7402e-06
# epoch 400, loss: 0.00234471, delta loss: 2.58279e-06
# Train L-BFGS:
# epoch 100, loss: 0.000673586, delta loss: 3.67872e-07
# epoch 200, loss: 0.000571961, delta loss: 9.28179e-07
# epoch 300, loss: 0.000474923, delta loss: 1.47469e-06
# epoch 400, loss: 0.000372577, delta loss: 1.40307e-06
# epoch 500, loss: 0.000320237, delta loss: 3.02942e-07
# Training time: 382.4016
# L2-error:  0.0049795397308774365
# Train L-BFGS:
# epoch 100, loss: 0.00026984, delta loss: 5.44911e-07
#
# New Partition
#
# Training time: 391.3095
# L2-error:  0.19604134003866586
# Train L-BFGS:
# epoch 100, loss: 2.02599, delta loss: 0.05007
# epoch 200, loss: 0.259226, delta loss: 0.0039601
# epoch 300, loss: 0.0643561, delta loss: 0.000262253
# epoch 400, loss: 0.033689, delta loss: 8.08276e-05
# epoch 500, loss: 0.0238721, delta loss: 0.000176553
# Training time: 405.1371
# L2-error:  0.005680250373946688
# Train L-BFGS:
# epoch 100, loss: 0.0150498, delta loss: 8.75443e-05
# epoch 200, loss: 0.0115649, delta loss: 3.73395e-05
# epoch 300, loss: 0.00695039, delta loss: 1.93184e-05
# epoch 400, loss: 0.00522551, delta loss: 7.62194e-06
# epoch 500, loss: 0.00414695, delta loss: 1.09235e-05
# Training time: 419.7054
# L2-error:  0.005373717151421073
# Train L-BFGS:
# epoch 100, loss: 0.00303774, delta loss: 9.70345e-06
# epoch 200, loss: 0.00232811, delta loss: 2.28127e-06
# epoch 300, loss: 0.00173703, delta loss: 3.96185e-06
# epoch 400, loss: 0.00123184, delta loss: 1.9474e-06
# epoch 500, loss: 0.00106585, delta loss: 2.30048e-06
# Training time: 433.9048
# L2-error:  0.005283217340804923
# Train L-BFGS:
# epoch 100, loss: 0.000927021, delta loss: 1.65438e-06
# epoch 200, loss: 0.000780053, delta loss: 8.78528e-07
# epoch 300, loss: 0.00068032, delta loss: 3.88129e-07
# epoch 400, loss: 0.000607075, delta loss: 8.8918e-07
# epoch 500, loss: 0.000517477, delta loss: 6.42613e-07
# Training time: 448.3391
# L2-error:  0.00520025853700675
# Train L-BFGS:
# epoch 100, loss: 0.000473368, delta loss: 4.8746e-07
#
# New Partition
#
# Training time: 457.4920
# L2-error:  0.17523110105721384
# Train L-BFGS:
# epoch 100, loss: 2.5264, delta loss: 0.04141
# epoch 200, loss: 0.260577, delta loss: 0.003883
# epoch 300, loss: 0.0751611, delta loss: 0.000425525
# epoch 400, loss: 0.0263251, delta loss: 0.000344098
# epoch 500, loss: 0.0142756, delta loss: 2.71453e-05
# Training time: 472.0251
# L2-error:  0.006052343747930695
# Train L-BFGS:
# epoch 100, loss: 0.011811, delta loss: 1.11749e-05
# epoch 200, loss: 0.0097681, delta loss: 7.67317e-06
# epoch 300, loss: 0.00856546, delta loss: 2.37022e-05
# epoch 400, loss: 0.00670706, delta loss: 4.58583e-06
# epoch 500, loss: 0.00572479, delta loss: 5.02588e-06
# epoch 200, loss: 0.00185931, delta loss: 1.37242e-06
# epoch 300, loss: 0.00177546, delta loss: 5.79748e-07
# epoch 400, loss: 0.00166118, delta loss: 1.97627e-06
# epoch 500, loss: 0.00158891, delta loss: 8.8301e-07
# Training time: 613.7134
# L2-error:  0.007259047680728039
# Train L-BFGS:
# epoch 100, loss: 0.00149235, delta loss: 1.86451e-06
# epoch 200, loss: 0.00138377, delta loss: 2.11503e-06
# epoch 300, loss: 0.0012556, delta loss: 5.43543e-07
# epoch 400, loss: 0.00120916, delta loss: 4.12227e-07
# epoch 500, loss: 0.00115493, delta loss: 4.94882e-07
# Training time: 628.6889
# L2-error:  0.007316979810699076
# Train L-BFGS:
#
# New Partition
#
# Training time: 636.5936
# L2-error:  0.18352440495541653
# Train L-BFGS:
# epoch 100, loss: 2.08672, delta loss: 0.0411165
# epoch 200, loss: 0.392804, delta loss: 0.00312233
# epoch 300, loss: 0.185595, delta loss: 0.00158247
# epoch 400, loss: 0.110792, delta loss: 0.00048627
# epoch 500, loss: 0.0750242, delta loss: 0.00036557
# Training time: 650.5648
# L2-error:  0.010378897272000403
# Train L-BFGS:
# epoch 100, loss: 0.0422477, delta loss: 0.000278309
# epoch 200, loss: 0.0219284, delta loss: 3.79216e-05
# epoch 300, loss: 0.0116428, delta loss: 4.08031e-05
# epoch 400, loss: 0.00911057, delta loss: 1.22124e-05
# epoch 500, loss: 0.0074007, delta loss: 2.65525e-05
# Training time: 665.0580
# L2-error:  0.008348913611296657
# Train L-BFGS:
# epoch 100, loss: 0.00608967, delta loss: 5.47757e-06
# epoch 200, loss: 0.00489465, delta loss: 6.7316e-06
# epoch 300, loss: 0.00444065, delta loss: 3.67733e-06
# epoch 400, loss: 0.00409506, delta loss: 5.24707e-06
# epoch 500, loss: 0.00382984, delta loss: 9.98145e-07
# Training time: 680.5140
# L2-error:  0.008300583201952285
# Train L-BFGS:
# epoch 100, loss: 0.00363902, delta loss: 4.42471e-06
# epoch 200, loss: 0.00340612, delta loss: 2.17836e-06
# epoch 300, loss: 0.00310116, delta loss: 2.95579e-06
# epoch 400, loss: 0.00283659, delta loss: 4.88502e-06
# epoch 500, loss: 0.00259445, delta loss: 1.02096e-06
# Training time: 694.8969
# L2-error:  0.008283383364688859
# Train L-BFGS:
# epoch 100, loss: 0.00244321, delta loss: 2.93972e-06
# epoch 200, loss: 0.00231769, delta loss: 8.51229e-07
# epoch 300, loss: 0.00226327, delta loss: 7.78586e-07
# epoch 400, loss: 0.00216699, delta loss: 1.14599e-06
# epoch 500, loss: 0.00202239, delta loss: 2.59513e-06
# Training time: 711.2003
# L2-error:  0.00830555605621492
# Train L-BFGS:
#
# End Condition
#
# Training time: 722.0317
# L2-error:  0.008312646010980397

# %% [markdown]
# ### Step 3.4: Make animation if figures were saved

# %%
if userPar['save_fig'] == 1:
    make_gif(userPar['model_name'])
